# %% [markdown]
# The aim of this notebook is to explore combinations of hyper-parameters to narrow down which could **possibly** perform better in future tests.
#
# The hyper-parameters to be tested here are:
# * Loss Function: MSE, MAPE
# * Activation Function: ReLU, Leaky ReLU, Parametric ReLU
# * Gradient Descent Optimizer: Adam, Adadelta, AMSGrad
# * Dropout Rate: 0.0, 0.1, 0.2
#
# This makes 54 models to be trained and evaluated according to a standard error. This error will be MSPE (Mean Square Percentage Error) because in all previous tests it has been **extremely** high.
#
# All the models try to predict HC.

# %%
from keras.models import Sequential, load_model, Model
from keras.layers import Input, Dense, Dropout, advanced_activations, BatchNormalization, LeakyReLU, PReLU
from keras import losses, optimizers, activations
import keras.backend as K

import h5py

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.externals import joblib
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import time
import datetime
import os

# %%
output_path = os.path.join('.','output')

# %% [markdown]
# ## Load Data

# %%
# This dataset was scaled using MinMax
data_scaled_shuffled = pd.read_csv('Dataset_Scaled_Shuffled.csv')
print('Shuffled dataset loaded.')
# Out:
# Shuffled dataset loaded.

# %% [markdown]
# ## Prepare Data

# %%
# Get number of data points
data_points = data_scaled_shuffled.shape[0]

# Set sizes for train, dev, test sets
train_percent = 0.8
train_size = round(train_percent*data_points)

if (data_points-train_size)%2 == 0:
    dev_size = int((data_points-train_size)/2)
    test_size = dev_size
    print('Train Size = {}'.format(train_size))
    print('Dev Size = {}'.format(dev_size))
    print('Test Size = {}'.format(test_size))
    print('Remainder = {}'.format(train_size+dev_size+test_size-data_points))
    
else:
    train_size = train_size-1
    dev_size = int((data_points-train_size)/2)
    test_size = dev_size 
    print('Train Size = {}'.format(train_size))
    print('Dev Size = {}'.format(dev_size))
    print('Test Size = {}'.format(test_size))
    print('Remainder = {}'.format(train_size+dev_size+test_size-data_points))
# Out:
# Train Size = 62511
# Dev Size = 7814
# Test Size = 7814
# Remainder = 0

# %%
# Divide data into train, dev, and test sets
train_set = data_scaled_shuffled[:train_size]
dev_set = data_scaled_shuffled[train_size:train_size+dev_size]
test_set = data_scaled_shuffled[train_size+dev_size:train_size+dev_size+test_size]

# Reset index for all sets
train_set = train_set.reset_index(drop=True)
dev_set = dev_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# Get values
train_set_values = train_set.values
dev_set_values = dev_set.values
test_set_values = test_set.values

# Number of emissions: HC, CO, CO2, NOX
n_out = 4

# SLICING: [start row:end row , start column:end column]
# Split into inputs and outputs
x_train = train_set_values[:,:-n_out]
x_dev = dev_set_values[:,:-n_out]
x_test = test_set_values[:,:-n_out]

HC_train = train_set_values[:,-n_out]
#CO_train = train_set_values[:,-n_out+1]
#CO2_train = train_set_values[:,-n_out+2]
#NOX_train = train_set_values[:,-n_out+3]

y_train = HC_train

HC_dev = dev_set_values[:,-n_out]
#CO_dev = dev_set_values[:,-n_out+1]
#CO2_dev = dev_set_values[:,-n_out+2]
#NOX_dev = dev_set_values[:,-n_out+3]

y_dev = HC_dev

HC_test = test_set_values[:,-n_out]
#CO_test = test_set_values[:,-n_out+1]
#CO2_test = test_set_values[:,-n_out+2]
#NOX_test = test_set_values[:,-n_out+3]

y_test = HC_test

# %% [markdown]
# ## Inverse Scaling of Data
#
# * This will be used later in the code to evaluate models
#
# #### Import scalers

# %%
# Create an empty list to put all the scalers
scalers = []

for i in range(np.size(data_scaled_shuffled.columns)):
    
    scaler_filename = "Scalers/scaler{}.save".format(i)
    scaler = joblib.load(scaler_filename)
    
    scalers.append(scaler)

# %% [markdown]
# #### Inverse Scale Data

# %%
# First, inverse transform all original values from the test_set
test_set_inverse = test_set.copy()

for i in range(np.size(data_scaled_shuffled.columns)):
    
    col_name = data_scaled_shuffled.columns[i]
    
    values = test_set_inverse[col_name].values
    values = values.astype('float64')
    values = values.reshape(values.shape[0],1)
    
    test_set_inverse[col_name] = scalers[i].inverse_transform(values)
    
    print('Success with feature: {}'.format(col_name))
# Out:
# Success with feature: Year
# Success with feature: Vehicle_Code
# Success with feature: Manufacturer_Code
# Success with feature: Displacement
# Success with feature: Fuel_System
# Success with feature: Gears
# Success with feature: Transmission_Code
# Success with feature: ETW
# Success with feature: HP
# Success with feature: Drive_System_Code
# Success with feature: Fuel_Code
# Success with feature: V_avg
# Success with feature: V_max
# Success with feature: V_std
# Success with feature: a_pos
# Success with feature: a_neg
# Success with feature: Peak_pos
# Success with feature: Peak_neg
# Success with feature: HC
# Success with feature: CO
# Success with feature: CO2
# Success with feature: Nox

# %% [markdown]
# -----------------
# ## Models

# %% [markdown]
# #### Basics

# %%
# Mini-batch size, epochs
batch_size = 64
epochs = 300

# %% [markdown]
# #### Variables

# %%
# Loss functions to try
names_losses = ['MSE','MAPE']    
dict_losses ={'MSE': losses.mean_squared_error,
              'MAPE': losses.mean_absolute_percentage_error}

#--------------------------------------------------------------------------------- 

# Activation functions to try
names_activations = ['ReLU', 'LReLU', 'PReLU']
    # A function has to be called so that a new instance of the function can be created in each layer
def get_activation(name):
    
    if name == 'ReLU':
        function = advanced_activations.ReLU()
    if name == 'LReLU':
        function = advanced_activations.LeakyReLU()
    if name == 'PReLU':
        function = advanced_activations.PReLU()
        
    return function

#---------------------------------------------------------------------------------     

# Optimizers to be tried out
names_optimizers = ['Adadelta', 'Adam', 'AMSGrad']
dict_optimizers ={'Adadelta': optimizers.Adadelta(),
                  'Adam': optimizers.Adam(amsgrad=False),
                  'AMSGrad':optimizers.Adam(amsgrad=True)}   

#--------------------------------------------------------------------------------- 

# Dropout rate to be tried
dropouts = [0.0, 0.1, 0.2]

#--------------------------------------------------------------------------------- 

print('Loss Functions = {}'.format(len(names_losses)))
print('Activation Functions = {}'.format(len(names_activations)))
print('Optimizers = {}'.format(len(names_optimizers)))
print('Dropout Rates = {}'.format(len(dropouts)))
print('--------------------------------')
print('Number of models for test = {}'.format(len(names_losses)*len(names_activations)*len(names_optimizers)*len(dropouts)))
# Out:
# Loss Functions = 2
# Activation Functions = 3
# Optimizers = 3
# Dropout Rates = 3
# --------------------------------
# Number of models for test = 54

# %% [markdown]
# #### Build Model

# %%
def build_model(number, loss_func, activation_name, optimizer, dd):
    
    # Create model
    model = Sequential(name='Model_{}'.format(number))

    model.add(Dense(256, input_dim=x_train.shape[1]))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(128))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(64))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(32))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(16))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(1))

    #Compile model
    model.compile(loss=loss_func, optimizer=optimizer, metrics = ['accuracy'])
    
    print('{} Created'.format(model.name))
    print('----------------------------------')
    
    return model

# %% [markdown]
# #### Train Model

# %%
def train_models(model):
    
    print('{} - Training'.format(model.name))
    print('- Started on {} at {}'.format(str(datetime.datetime.now())[5:-16], str(datetime.datetime.now())[11:-10]))
    # Start timer
    start_time = time.time()

    # fit network
    history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(x_dev, y_dev), verbose=0, shuffle=True)

    # End timer
    end_time = time.time() - start_time
    print('{} - Training Complete'.format(model.name))
    print('- Time: {:.3f} min'.format(end_time/60))
    print('- Loss = {:.5f}'.format(history.history['loss'][-1]))
    print('- Val Loss = {:.5f}'.format(history.history['val_loss'][-1]))
    print('----------------------------------')
        
    return history

# %% [markdown]
# #### Make Predictions and Calculate Error

# %%
# Function to define MSPE
def msp_error(true,pred):
    error = 100*np.sum(((true-pred)/true)**2)/np.size(true)
    return error

# %%
def predict_get_error(model):
    
    print('Predicting with {}'.format(model.name))
    predictions = model.predict(x_test)
    
    print('Inverse Scaling Operation')        
    # Inverse the scaling operation on the predictions (only HC is being predicted)
    HC_predict = scalers[-4].inverse_transform(predictions)
    
    print('Calculating Error')
    mspe = msp_error(test_set_inverse['HC'].values, HC_predict)
    print('- HC Error  = {:.2e}'.format(mspe))
    print('----------------------------------')
    
    return mspe

# %% [markdown]
# #### Process Models and Rank with MSPE

# %%
def process_models():
    
    count = 1
    model_list = []
    history_list = []
    HC_error_list = []

    for loss_name in names_losses:
        loss = dict_losses[loss_name]

        for activation_name in names_activations:

            for optimizer_name in names_optimizers:
                optimizer = dict_optimizers[optimizer_name]

                for dd in dropouts:

                    # Print model variables
                    print('Model_{} Variables:'.format(count))
                    print('- Loss: {}'.format(loss_name))
                    print('- Activation: {}'.format(activation_name))
                    print('- Optimizer: {}'.format(optimizer_name))
                    print('- Dropout: {}%'.format(dd*100))
                    print('----------------------------------')

                    # Create model
                    model = build_model(count,loss,activation_name,optimizer,dd)
                    model_list.append(model)

                    # Train model
                    history = train_models(model)
                    history_list.append(history)

                    # Make predictions and calculate error
                    error = predict_get_error(model)
                    HC_error_list.append([model.name, loss_name, activation_name, optimizer_name, dd, error])

                    # Announce one model process ended
                    print('============== MODEL {} PROCESS END =============='.format(count))
                    print(' ')

                    # Increase counter by 1
                    count = count+1

    print('Creating DataFrame')                
    HC_error = pd.DataFrame(HC_error_list)

    print('Changing DataFrame column names')
    HC_error.columns = ['Model', 'Loss', 'Activation', 'Optimizer', 'Dropout', 'MSPE']

    print('Ranking Models')
    HC_error.sort_values(by=['MSPE'], inplace=True)

    count = 0
    
    return HC_error, model_list, history_list

# %%
ranking, models, histories = process_models()
# Out:
# Model_1 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_1 Created
# ----------------------------------
# Model_1 - Training
# - Started on 03-23 at 18:31
# Model_1 - Training Complete
# - Time: 39.336 min
# - Loss = 0.00216
# - Val Loss = 0.00195
# ----------------------------------
# Predicting with Model_1
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.63e+11
# ----------------------------------
# ============== MODEL 1 PROCESS END ==============
#
# Model_2 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_2 Created
# ----------------------------------
# Model_2 - Training
# - Started on 03-23 at 19:11
# Model_2 - Training Complete
# - Time: 41.556 min
# - Loss = 0.00253
# - Val Loss = 0.00212
# ----------------------------------
# Predicting with Model_2
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.33e+11
# ----------------------------------
# ============== MODEL 2 PROCESS END ==============
#
# Model_3 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_3 Created
# ----------------------------------
# Model_3 - Training
# - Started on 03-23 at 19:52
# Model_3 - Training Complete
# - Time: 41.509 min
# - Loss = 0.00276
# - Val Loss = 0.00214
# ----------------------------------
# Predicting with Model_3
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.47e+11
# ----------------------------------
# ============== MODEL 3 PROCESS END ==============
#
# Model_4 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_4 Created
# ----------------------------------
# Model_4 - Training
# - Started on 03-23 at 20:34
# Model_4 - Training Complete
# - Time: 37.520 min
# - Loss = 0.00191
# - Val Loss = 0.00192
# ----------------------------------
# Predicting with Model_4
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.75e+11
# ----------------------------------
# ============== MODEL 4 PROCESS END ==============
#
# Model_5 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_5 Created
# ----------------------------------
# Model_5 - Training
# - Started on 03-23 at 21:11
# Model_5 - Training Complete
# - Time: 39.890 min
# - Loss = 0.00245
# - Val Loss = 0.00203
# ----------------------------------
# Predicting with Model_5
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.47e+11
# ----------------------------------
# ============== MODEL 5 PROCESS END ==============
#
# Model_6 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_6 Created
# ----------------------------------
# Model_6 - Training
# - Started on 03-23 at 21:51
# Model_6 - Training Complete
# - Time: 39.887 min
# - Loss = 0.00272
# - Val Loss = 0.00223
# ----------------------------------
# Predicting with Model_6
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.34e+11
# ----------------------------------
# ============== MODEL 6 PROCESS END ==============
#
# Model_7 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_7 Created
# ----------------------------------
# Model_7 - Training
# - Started on 03-23 at 22:31
# Model_7 - Training Complete
# - Time: 41.041 min
# - Loss = 0.00264
# - Val Loss = 0.00240
# ----------------------------------
# Predicting with Model_7
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.62e+11
# ----------------------------------
# ============== MODEL 7 PROCESS END ==============
#
# Model_8 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_8 Created
# ----------------------------------
# Model_8 - Training
# - Started on 03-23 at 23:12
# Model_8 - Training Complete
# - Time: 41.597 min
# - Loss = 0.00302
# - Val Loss = 0.00256
# ----------------------------------
# Predicting with Model_8
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.35e+11
# ----------------------------------
# ============== MODEL 8 PROCESS END ==============
#
# Model_9 Variables:
# - Loss: MSE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_9 Created
# ----------------------------------
# Model_9 - Training
# - Started on 03-23 at 23:54
# Model_9 - Training Complete
# - Time: 41.938 min
# - Loss = 0.00322
# - Val Loss = 0.00267
# ----------------------------------
# Predicting with Model_9
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.31e+11
# ----------------------------------
# ============== MODEL 9 PROCESS END ==============
#
# Model_10 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_10 Created
# ----------------------------------
# Model_10 - Training
# - Started on 03-24 at 00:36
# Model_10 - Training Complete
# - Time: 42.381 min
# - Loss = 0.00236
# - Val Loss = 0.00207
# ----------------------------------
# Predicting with Model_10
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.51e+11
# ----------------------------------
# ============== MODEL 10 PROCESS END ==============
#
# Model_11 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_11 Created
# ----------------------------------
# Model_11 - Training
# - Started on 03-24 at 01:18
# Model_11 - Training Complete
# - Time: 44.447 min
# - Loss = 0.00292
# - Val Loss = 0.00247
# ----------------------------------
# Predicting with Model_11
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.46e+11
# ----------------------------------
# ============== MODEL 11 PROCESS END ==============
#
# Model_12 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_12 Created
# ----------------------------------
# Model_12 - Training
# - Started on 03-24 at 02:03
# Model_12 - Training Complete
# - Time: 44.639 min
# - Loss = 0.00305
# - Val Loss = 0.00262
# ----------------------------------
# Predicting with Model_12
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.44e+11
# ----------------------------------
# ============== MODEL 12 PROCESS END ==============
#
# Model_13 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_13 Created
# ----------------------------------
# Model_13 - Training
# - Started on 03-24 at 02:47
# Model_13 - Training Complete
# - Time: 40.799 min
# - Loss = 0.00216
# - Val Loss = 0.00194
# ----------------------------------
# Predicting with Model_13
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.63e+11
# ----------------------------------
# ============== MODEL 13 PROCESS END ==============
#
# Model_14 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_14 Created
# ----------------------------------
# Model_14 - Training
# - Started on 03-24 at 03:28
# Model_14 - Training Complete
# - Time: 42.920 min
# - Loss = 0.00252
# - Val Loss = 0.00204
# ----------------------------------
# Predicting with Model_14
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.54e+11
# ----------------------------------
# ============== MODEL 14 PROCESS END ==============
#
# Model_15 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_15 Created
# ----------------------------------
# Model_15 - Training
# - Started on 03-24 at 04:11
# Model_15 - Training Complete
# - Time: 43.110 min
# - Loss = 0.00272
# - Val Loss = 0.00209
# ----------------------------------
# Predicting with Model_15
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.48e+11
# ----------------------------------
# ============== MODEL 15 PROCESS END ==============
#
# Model_16 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_16 Created
# ----------------------------------
# Model_16 - Training
# - Started on 03-24 at 04:54
# Model_16 - Training Complete
# - Time: 43.264 min
# - Loss = 0.00263
# - Val Loss = 0.00236
# ----------------------------------
# Predicting with Model_16
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.52e+11
# ----------------------------------
# ============== MODEL 16 PROCESS END ==============
#
# Model_17 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_17 Created
# ----------------------------------
# Model_17 - Training
# - Started on 03-24 at 05:38
# Model_17 - Training Complete
# - Time: 44.917 min
# - Loss = 0.00316
# - Val Loss = 0.00284
# ----------------------------------
# Predicting with Model_17
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.82e+11
# ----------------------------------
# ============== MODEL 17 PROCESS END ==============
#
# Model_18 Variables:
# - Loss: MSE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_18 Created
# ----------------------------------
# Model_18 - Training
# - Started on 03-24 at 06:23
# Model_18 - Training Complete
# - Time: 45.098 min
# - Loss = 0.00334
# - Val Loss = 0.00284
# ----------------------------------
# Predicting with Model_18
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.50e+11
# ----------------------------------
# ============== MODEL 18 PROCESS END ==============
#
# Model_19 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_19 Created
# ----------------------------------
# Model_19 - Training
# - Started on 03-24 at 07:08
# Model_19 - Training Complete
# - Time: 47.807 min
# - Loss = 0.00209
# - Val Loss = 0.00190
# ----------------------------------
# Predicting with Model_19
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.51e+11
# ----------------------------------
# ============== MODEL 19 PROCESS END ==============
#
# Model_20 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_20 Created
# ----------------------------------
# Model_20 - Training
# - Started on 03-24 at 07:56
# Model_20 - Training Complete
# - Time: 50.085 min
# - Loss = 0.00251
# - Val Loss = 0.00205
# ----------------------------------
# Predicting with Model_20
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.40e+11
# ----------------------------------
# ============== MODEL 20 PROCESS END ==============
#
# Model_21 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_21 Created
# ----------------------------------
# Model_21 - Training
# - Started on 03-24 at 08:46
# Model_21 - Training Complete
# - Time: 50.383 min
# - Loss = 0.00268
# - Val Loss = 0.00212
# ----------------------------------
# Predicting with Model_21
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.41e+11
# ----------------------------------
# ============== MODEL 21 PROCESS END ==============
#
# Model_22 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_22 Created
# ----------------------------------
# Model_22 - Training
# - Started on 03-24 at 09:36
# Model_22 - Training Complete
# - Time: 45.923 min
# - Loss = 0.00181
# - Val Loss = 0.00189
# ----------------------------------
# Predicting with Model_22
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.80e+11
# ----------------------------------
# ============== MODEL 22 PROCESS END ==============
#
# Model_23 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_23 Created
# ----------------------------------
# Model_23 - Training
# - Started on 03-24 at 10:22
# Model_23 - Training Complete
# - Time: 48.868 min
# - Loss = 0.00223
# - Val Loss = 0.00193
# ----------------------------------
# Predicting with Model_23
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.80e+11
# ----------------------------------
# ============== MODEL 23 PROCESS END ==============
#
# Model_24 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_24 Created
# ----------------------------------
# Model_24 - Training
# - Started on 03-24 at 11:11
# Model_24 - Training Complete
# - Time: 50.481 min
# - Loss = 0.00242
# - Val Loss = 0.00197
# ----------------------------------
# Predicting with Model_24
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.53e+11
# ----------------------------------
# ============== MODEL 24 PROCESS END ==============
#
# Model_25 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_25 Created
# ----------------------------------
# Model_25 - Training
# - Started on 03-24 at 12:02
# Model_25 - Training Complete
# - Time: 48.934 min
# - Loss = 0.00234
# - Val Loss = 0.00203
# ----------------------------------
# Predicting with Model_25
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.62e+11
# ----------------------------------
# ============== MODEL 25 PROCESS END ==============
#
# Model_26 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_26 Created
# ----------------------------------
# Model_26 - Training
# - Started on 03-24 at 12:51
# Model_26 - Training Complete
# - Time: 52.168 min
# - Loss = 0.00293
# - Val Loss = 0.00246
# ----------------------------------
# Predicting with Model_26
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.42e+11
# ----------------------------------
# ============== MODEL 26 PROCESS END ==============
#
# Model_27 Variables:
# - Loss: MSE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_27 Created
# ----------------------------------
# Model_27 - Training
# - Started on 03-24 at 13:43
# Model_27 - Training Complete
# - Time: 53.068 min
# - Loss = 0.00313
# - Val Loss = 0.00262
# ----------------------------------
# Predicting with Model_27
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.47e+11
# ----------------------------------
# ============== MODEL 27 PROCESS END ==============
#
# Model_28 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_28 Created
# ----------------------------------
# Model_28 - Training
# - Started on 03-24 at 14:36
# Model_28 - Training Complete
# - Time: 49.208 min
# - Loss = 669.21889
# - Val Loss = 213.50501
# ----------------------------------
# Predicting with Model_28
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 2.30e+12
# ----------------------------------
# ============== MODEL 28 PROCESS END ==============
#
# Model_29 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_29 Created
# ----------------------------------
# Model_29 - Training
# - Started on 03-24 at 15:25
# Model_29 - Training Complete
# - Time: 54.381 min
# - Loss = 308.36161
# - Val Loss = 96.59211
# ----------------------------------
# Predicting with Model_29
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 4.11e+12
# ----------------------------------
# ============== MODEL 29 PROCESS END ==============
#
# Model_30 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_30 Created
# ----------------------------------
# Model_30 - Training
# - Started on 03-24 at 16:20
# Model_30 - Training Complete
# - Time: 52.797 min
# - Loss = 218.05890
# - Val Loss = 110.38816
# ----------------------------------
# Predicting with Model_30
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.86e+09
# ----------------------------------
# ============== MODEL 30 PROCESS END ==============
#
# Model_31 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_31 Created
# ----------------------------------
# Model_31 - Training
# - Started on 03-24 at 17:13
# Model_31 - Training Complete
# - Time: 48.563 min
# - Loss = 826.24795
# - Val Loss = 130.93106
# ----------------------------------
# Predicting with Model_31
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.79e+09
# ----------------------------------
# ============== MODEL 31 PROCESS END ==============
#
# Model_32 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_32 Created
# ----------------------------------
# Model_32 - Training
# - Started on 03-24 at 18:01
# Model_32 - Training Complete
# - Time: 49.190 min
# - Loss = 806.24804
# - Val Loss = 228.15783
# ----------------------------------
# Predicting with Model_32
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.15e+13
# ----------------------------------
# ============== MODEL 32 PROCESS END ==============
#
# Model_33 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_33 Created
# ----------------------------------
# Model_33 - Training
# - Started on 03-24 at 18:51
# Model_33 - Training Complete
# - Time: 49.632 min
# - Loss = 630.52380
# - Val Loss = 2425.23381
# ----------------------------------
# Predicting with Model_33
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 2.61e+17
# ----------------------------------
# ============== MODEL 33 PROCESS END ==============
#
# Model_34 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_34 Created
# ----------------------------------
# Model_34 - Training
# - Started on 03-24 at 19:40
# Model_34 - Training Complete
# - Time: 49.502 min
# - Loss = 988.66345
# - Val Loss = 96.11446
# ----------------------------------
# Predicting with Model_34
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 5.02e+09
# ----------------------------------
# ============== MODEL 34 PROCESS END ==============
#
# Model_35 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_35 Created
# ----------------------------------
# Model_35 - Training
# - Started on 03-24 at 20:30
# Model_35 - Training Complete
# - Time: 52.527 min
# - Loss = 779.80919
# - Val Loss = 169.23307
# ----------------------------------
# Predicting with Model_35
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.05e+10
# ----------------------------------
# ============== MODEL 35 PROCESS END ==============
#
# Model_36 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_36 Created
# ----------------------------------
# Model_36 - Training
# - Started on 03-24 at 21:22
# Model_36 - Training Complete
# - Time: 50.536 min
# - Loss = 887.20317
# - Val Loss = 95.23001
# ----------------------------------
# Predicting with Model_36
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 2.90e+09
# ----------------------------------
# ============== MODEL 36 PROCESS END ==============
#
# Model_37 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_37 Created
# ----------------------------------
# Model_37 - Training
# - Started on 03-24 at 22:13
# Model_37 - Training Complete
# - Time: 51.133 min
# - Loss = 720.55005
# - Val Loss = 118.35214
# ----------------------------------
# Predicting with Model_37
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 5.99e+09
# ----------------------------------
# ============== MODEL 37 PROCESS END ==============
#
# Model_38 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_38 Created
# ----------------------------------
# Model_38 - Training
# - Started on 03-24 at 23:04
# Model_38 - Training Complete
# - Time: 53.997 min
# - Loss = 276.99451
# - Val Loss = 99.72412
# ----------------------------------
# Predicting with Model_38
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 7.64e+09
# ----------------------------------
# ============== MODEL 38 PROCESS END ==============
#
# Model_39 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_39 Created
# ----------------------------------
# Model_39 - Training
# - Started on 03-24 at 23:58
# Model_39 - Training Complete
# - Time: 53.771 min
# - Loss = 226.01205
# - Val Loss = 94.38107
# ----------------------------------
# Predicting with Model_39
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 2.30e+09
# ----------------------------------
# ============== MODEL 39 PROCESS END ==============
#
# Model_40 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_40 Created
# ----------------------------------
# Model_40 - Training
# - Started on 03-25 at 00:52
# Model_40 - Training Complete
# - Time: 49.434 min
# - Loss = 679.75042
# - Val Loss = 132.15797
# ----------------------------------
# Predicting with Model_40
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 8.19e+07
# ----------------------------------
# ============== MODEL 40 PROCESS END ==============
#
# Model_41 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_41 Created
# ----------------------------------
# Model_41 - Training
# - Started on 03-25 at 01:42
# Model_41 - Training Complete
# - Time: 52.214 min
# - Loss = 625.47627
# - Val Loss = 132.45536
# ----------------------------------
# Predicting with Model_41
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 5.82e+07
# ----------------------------------
# ============== MODEL 41 PROCESS END ==============
#
# Model_42 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_42 Created
# ----------------------------------
# Model_42 - Training
# - Started on 03-25 at 02:34
# Model_42 - Training Complete
# - Time: 52.251 min
# - Loss = 523.93479
# - Val Loss = 127.02903
# ----------------------------------
# Predicting with Model_42
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 4.76e+07
# ----------------------------------
# ============== MODEL 42 PROCESS END ==============
#
# Model_43 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_43 Created
# ----------------------------------
# Model_43 - Training
# - Started on 03-25 at 03:26
# Model_43 - Training Complete
# - Time: 52.610 min
# - Loss = 792.07735
# - Val Loss = 102.55197
# ----------------------------------
# Predicting with Model_43
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 5.73e+09
# ----------------------------------
# ============== MODEL 43 PROCESS END ==============
#
# Model_44 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_44 Created
# ----------------------------------
# Model_44 - Training
# - Started on 03-25 at 04:19
# Model_44 - Training Complete
# - Time: 55.228 min
# - Loss = 562.86787
# - Val Loss = 132.15303
# ----------------------------------
# Predicting with Model_44
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.97e+09
# ----------------------------------
# ============== MODEL 44 PROCESS END ==============
#
# Model_45 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_45 Created
# ----------------------------------
# Model_45 - Training
# - Started on 03-25 at 05:14
# Model_45 - Training Complete
# - Time: 55.901 min
# - Loss = 636.39818
# - Val Loss = 188.85772
# ----------------------------------
# Predicting with Model_45
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.64e+09
# ----------------------------------
# ============== MODEL 45 PROCESS END ==============
#
# Model_46 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 0.0%
# ----------------------------------
# Model_46 Created
# ----------------------------------
# Model_46 - Training
# - Started on 03-25 at 06:10
# Model_46 - Training Complete
# - Time: 57.900 min
# - Loss = 601.97097
# - Val Loss = 158.32568
# ----------------------------------
# Predicting with Model_46
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.28e+11
# ----------------------------------
# ============== MODEL 46 PROCESS END ==============
#
# Model_47 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 10.0%
# ----------------------------------
# Model_47 Created
# ----------------------------------
# Model_47 - Training
# - Started on 03-25 at 07:08
# Model_47 - Training Complete
# - Time: 59.974 min
# - Loss = 273.14366
# - Val Loss = 90.52166
# ----------------------------------
# Predicting with Model_47
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 5.74e+09
# ----------------------------------
# ============== MODEL 47 PROCESS END ==============
#
# Model_48 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adadelta
# - Dropout: 20.0%
# ----------------------------------
# Model_48 Created
# ----------------------------------
# Model_48 - Training
# - Started on 03-25 at 08:08
# Model_48 - Training Complete
# - Time: 61.229 min
# - Loss = 203.33634
# - Val Loss = 87.78839
# ----------------------------------
# Predicting with Model_48
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 1.11e+09
# ----------------------------------
# ============== MODEL 48 PROCESS END ==============
#
# Model_49 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 0.0%
# ----------------------------------
# Model_49 Created
# ----------------------------------
# Model_49 - Training
# - Started on 03-25 at 09:10
# Model_49 - Training Complete
# - Time: 56.922 min
# - Loss = 674.43140
# - Val Loss = 175.92957
# ----------------------------------
# Predicting with Model_49
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 4.95e+08
# ----------------------------------
# ============== MODEL 49 PROCESS END ==============
#
# Model_50 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 10.0%
# ----------------------------------
# Model_50 Created
# ----------------------------------
# Model_50 - Training
# - Started on 03-25 at 10:07
# Model_50 - Training Complete
# - Time: 59.775 min
# - Loss = 645.56274
# - Val Loss = 227.93263
# ----------------------------------
# Predicting with Model_50
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 8.83e+08
# ----------------------------------
# ============== MODEL 50 PROCESS END ==============
#
# Model_51 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# ----------------------------------
# Model_51 Created
# ----------------------------------
# Model_51 - Training
# - Started on 03-25 at 11:07
# Model_51 - Training Complete
# - Time: 61.365 min
# - Loss = 621.73757
# - Val Loss = 204.62187
# ----------------------------------
# Predicting with Model_51
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 6.19e+08
# ----------------------------------
# ============== MODEL 51 PROCESS END ==============
#
# Model_52 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 0.0%
# ----------------------------------
# Model_52 Created
# ----------------------------------
# Model_52 - Training
# - Started on 03-25 at 12:08
# Model_52 - Training Complete
# - Time: 63.430 min
# - Loss = 878.20967
# - Val Loss = 131.77099
# ----------------------------------
# Predicting with Model_52
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 6.01e+09
# ----------------------------------
# ============== MODEL 52 PROCESS END ==============
#
# Model_53 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 10.0%
# ----------------------------------
# Model_53 Created
# ----------------------------------
# Model_53 - Training
# - Started on 03-25 at 13:12
# Model_53 - Training Complete
# - Time: 63.205 min
# - Loss = 1189.25850
# - Val Loss = 152.99893
# ----------------------------------
# Predicting with Model_53
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 6.20e+09
# ----------------------------------
# ============== MODEL 53 PROCESS END ==============
#
# Model_54 Variables:
# - Loss: MAPE
# - Activation: PReLU
# - Optimizer: AMSGrad
# - Dropout: 20.0%
# ----------------------------------
# Model_54 Created
# ----------------------------------
# Model_54 - Training
# - Started on 03-25 at 14:15
# Model_54 - Training Complete
# - Time: 63.352 min
# - Loss = 1595.59851
# - Val Loss = 184.11148
# ----------------------------------
# Predicting with Model_54
# Inverse Scaling Operation
# Calculating Error
# - HC Error  = 8.40e+09
# ----------------------------------
# ============== MODEL 54 PROCESS END ==============
#
# Creating DataFrame
# Changing DataFrame column names
# Ranking Models

# %%
ranking
# Out:
#        Model  Loss Activation Optimizer  Dropout          MSPE
# 41  Model_42  MAPE      LReLU      Adam      0.2  4.758262e+07
# 40  Model_41  MAPE      LReLU      Adam      0.1  5.824725e+07
# 39  Model_40  MAPE      LReLU      Adam      0.0  8.193457e+07
# 48  Model_49  MAPE      PReLU      Adam      0.0  4.953015e+08
# 50  Model_51  MAPE      PReLU      Adam      0.2  6.187472e+08
# 49  Model_50  MAPE      PReLU      Adam      0.1  8.833102e+08
# 47  Model_48  MAPE      PReLU  Adadelta      0.2  1.110413e+09
# 44  Model_45  MAPE      LReLU   AMSGrad      0.2  1.641920e+09
# 30  Model_31  MAPE       ReLU      Adam      0.0  1.788013e+09
# 29  Model_30  MAPE       ReLU  Adadelta      0.2  1.857675e+09
# 43  Model_44  MAPE      LReLU   AMSGrad      0.1  1.967037e+09
# 38  Model_39  MAPE      LReLU  Adadelta      0.2  2.301409e+09
# 35  Model_36  MAPE       ReLU   AMSGrad      0.2  2.903466e+09
# 33  Model_34  MAPE       ReLU   AMSGrad      0.0  5.018661e+09
# 42  Model_43  MAPE      LReLU   AMSGrad      0.0  5.731405e+09
# 46  Model_47  MAPE      PReLU  Adadelta      0.1  5.739579e+09
# 36  Model_37  MAPE      LReLU  Adadelta      0.0  5.994404e+09
# 51  Model_52  MAPE      PReLU   AMSGrad      0.0  6.005404e+09
# 52  Model_53  MAPE      PReLU   AMSGrad      0.1  6.204385e+09
# 37  Model_38  MAPE      LReLU  Adadelta      0.1  7.642285e+09
# 53  Model_54  MAPE      PReLU   AMSGrad      0.2  8.402107e+09
# 34  Model_35  MAPE       ReLU   AMSGrad      0.1  1.053567e+10
# 45  Model_46  MAPE      PReLU  Adadelta      0.0  1.275344e+11
# 8    Model_9   MSE       ReLU   AMSGrad      0.2  1.309337e+11
# 1    Model_2   MSE       ReLU  Adadelta      0.1  1.333895e+11
# 5    Model_6   MSE       ReLU      Adam      0.2  1.342095e+11
# 7    Model_8   MSE       ReLU   AMSGrad      0.1  1.348961e+11
# 19  Model_20   MSE      PReLU  Adadelta      0.1  1.400339e+11
# 20  Model_21   MSE      PReLU  Adadelta      0.2  1.405615e+11
# 25  Model_26   MSE      PReLU   AMSGrad      0.1  1.418383e+11
# 11  Model_12   MSE      LReLU  Adadelta      0.2  1.443024e+11
# 10  Model_11   MSE      LReLU  Adadelta      0.1  1.456675e+11
# 2    Model_3   MSE       ReLU  Adadelta      0.2  1.469029e+11
# 4    Model_5   MSE       ReLU      Adam      0.1  1.469467e+11
# 26  Model_27   MSE      PReLU   AMSGrad      0.2  1.469522e+11
# 14  Model_15   MSE      LReLU      Adam      0.2  1.480058e+11
# 17  Model_18   MSE      LReLU   AMSGrad      0.2  1.495140e+11
# 9   Model_10   MSE      LReLU  Adadelta      0.0  1.505362e+11
# 18  Model_19   MSE      PReLU  Adadelta      0.0  1.508394e+11
# 15  Model_16   MSE      LReLU   AMSGrad      0.0  1.519529e+11
# 23  Model_24   MSE      PReLU      Adam      0.2  1.533453e+11
# 13  Model_14   MSE      LReLU      Adam      0.1  1.541999e+11
# 6    Model_7   MSE       ReLU   AMSGrad      0.0  1.619914e+11
# 24  Model_25   MSE      PReLU   AMSGrad      0.0  1.623052e+11
# 12  Model_13   MSE      LReLU      Adam      0.0  1.630173e+11
# 0    Model_1   MSE       ReLU  Adadelta      0.0  1.633718e+11
# 3    Model_4   MSE       ReLU      Adam      0.0  1.747897e+11
# 21  Model_22   MSE      PReLU      Adam      0.0  1.800235e+11
# 22  Model_23   MSE      PReLU      Adam      0.1  1.800895e+11
# 16  Model_17   MSE      LReLU   AMSGrad      0.1  1.821074e+11
# 27  Model_28  MAPE       ReLU  Adadelta      0.0  2.296983e+12
# 28  Model_29  MAPE       ReLU  Adadelta      0.1  4.112458e+12
# 31  Model_32  MAPE       ReLU      Adam      0.1  1.146885e+13
# 32  Model_33  MAPE       ReLU      Adam      0.2  2.610147e+17

# %%
epoch_vector = np.linspace(1,epochs,epochs)

for i in [39,40,41,48,49,50]:
    
    model = models[i]
    history = histories[i]
    
    model.save(os.path.join(output_path,'{}.h5'.format(model.name)))
    
    
    hist_data = [epoch_vector, history.history['loss'], history.history['val_loss']]
    
    hist_data = pd.DataFrame(hist_data).transpose()
    
    # Change column names
    hist_data.columns = ['Epochs','loss','val_loss']
    
    hist_data.to_csv(os.path.join(output_path,'Training_History_{}.csv'.format(model.name)), 
                     encoding='utf-8', index=False)

# %%
ranking.to_csv(os.path.join(output_path,'Model_Ranking.csv'), encoding='utf-8', index=False)

# %% [markdown]
# ## Next Steps

# %% [markdown]
# All the data will be moved from the *output* folder to the *Gen_3* folder. Top six models were saved for reference. The error is so big they probably won't be used again.
#
# Pick the best combinations (with some flexibility - all errors are through the roof):
# * MAPE + Leaky ReLU + Adam + 20% Dropout
# * MAPE + Leaky ReLU + Adadelta + 20% Dropout
# * MAPE + PReLU + Adam + 20% Dropout
# * MAPE + PReLU + Adadelta + 20% Dropout
#
# The outputs being predicted by the neural networks are **NEGATIVE**, which makes no sense. The problem could lie within the **linear** activation function in the output neuron. Train those configurations using a different function like ReLU or Sigmoid
#
# #### Other possible next steps
# * Try predicting another pollutant besides HC
# * Try the R2 loss function
# * Try varying the input variables

# %%
# Print model description
#print('{} Description:'.format(model.name))
#print('- Loss: {}'.format(str(model.loss)[10:-23]))
#print('- Optimizer: {}'.format(str(model.optimizer)[18:-29]))



#total_count = model.count_params()
#trainable_count = int(np.sum([K.count_params(p) for p in set(model.trainable_weights)]))
#non_trainable_count = int(np.sum([K.count_params(p) for p in set(model.non_trainable_weights)]))
#print('- Total params: {:,}'.format(total_count))
#print('- Trainable params: {:,}'.format(trainable_count))
#print('- Non-trainable params: {:,}'.format(non_trainable_count))
