# %% [markdown]
# ## Description
#
# This notebook represents the culmination of a long road of trial and error trying to predict vehicle emissions using neural networks.
#
# ### What has been done until now:
#
# * Construct database of inputs and outputs
# * Remove zeros from data to prevent unnecessary noise
# * Try Multi Task Learning to predict: $HC$, $CO$, $CO_2$, $NO_X$
#     * This didn't work
# * Run a short code trying to evaluate the impact of network size on the predictions
#     * It was found the effect was minimal at that point, so ONE architecture was chosen: inputs-256-128-64-32-16-output
# * Try Single Task Learning (normal supervised learning) to predict only HC
# * Perform a **hyper-parameter** search to find the best possible combination that would reduce the error
#     * For this a standard error was chosen to evaluate the predictions: MSPE
#     * The top four were:
#         * MAPE + LReLU + Adam + 20% dropout
#         * MAPE + PReLU + Adam + 20% dropout
#         * R2 + LReLU + Adam + 20% dropout
#         * R2 + PReLU + Adam + 20% dropout
#     * The models were predicting **negative** values which made no sense
# * These top four models were tested for all four pollutants: $HC$, $CO$, $CO_2$, $NO_X$
#     * To see if one of them could be predicted better than the others and this could provide a clue into the massive errors
#     * Because in the past notebook the predictions were negative, a ReLU output replaced the Linear output. But this caused all of the predictions to be **zero** for all emissions
# * The hypothesis was that probably one of the inputs was introducing a VERY negative correlation into the relationship which made the predictions zero. So 18 different data-sets were created, where each was missing **one** input. Models were trained (with a linear output) to see when they generated positive predictions and when they were negative.
#     * It was found that the following variables made the predictions negative:
#         * Fuel Code
#         * Drive System
#         * Peak_pos (Positive acceleration peaks)
#         * ETW (Estimated Test Weight)
#         * a_pos (Positive acceleration mean)
#         * HP (Horse Power)
#     * It was impossible to try combinations of two of those variables because there would be around 300 models to test
# * PCA (Principal Component Analysis) was applied on the original data-set (with 18 inputs) to see if this algorithm could generate variables that would improve predictions.
#     * It didn't work
# * PCA was applied on a new data-set that did not include the **six** variables from above.
#     * This didn't work either
#
# ### This Notebook:
#
# This notebook will run a test to see if a model can accurately predict emissions for vehicles belonging to **ONE SINGLE MANUFACTURER**. A combination of hyper-parameters will be tried to see if something works:
#
# * Activation Functions:
#     * Leaky ReLU + Linear Output
#     * Leaky ReLU + ReLU Output
#     * ReLU + Linear Output
#     * ReLU + ReLU
# * Optimizers:
#     * Adam
# * Dropout:
#     * 20%
# * Loss Function:
#     * MAPE (Mean Absolute Percentage Error)
# * Scaler:
#     * MinMax
#
# There will be an analysis of the manufacturers in the data-base and with this, different data-sets to train the models will be created.
#
#     1) Create a data-set with 18 inputs for the manufacturer with the most cars
#     2) Create 18 independent databases by dropping one input at a time
#     3) Apply PCA for 99% and 90% to the first database
#
# This totals 78 models to be trained and tested

# %% [markdown]
# -------
#
# ## TO DO's
#
# Load original shuffled and scaled data
#
# Data Scaling
# * Load MinMax Scalers
# * Inverse the data
# * Re-scale the data using the selected scaler (MinMax or Standard)
#     * This has to be a function where the scaler is chosen and also the data-set
#
# Data Processing
# * Get a list of manufacturers
# * Count how many entries each one has
# * Rank them by the number of entries
# * Create one database:
#     * One for the TOP manufacturer
# * Write code to create a new database for each dropped variable (**after scaling**)
#
#
# Data Pre-Processing
# * Function to create x_train, x_dev, x_test, and y_train, y_dev, y_test based on the database that is fed to it
#
# Hyper-Parameters
# * Create the hyper-parameter space to be explored
#
# PCA
# * Function to apply PCA by feeding the **x**'s
# * This will be used later
#
# Models
# * Function to create models based on the hyper-parameter combinations

# %%
from keras.models import Sequential, load_model, Model
from keras.layers import Input, Dense, Dropout, advanced_activations, BatchNormalization, LeakyReLU
from keras import losses, optimizers, activations
import keras.backend as K

import h5py

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.externals import joblib
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import time
import datetime
import os
# Out:
# C:\Users\drllc\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
output_path = os.path.join('.','output')
minmax_scaler_path = os.path.join('.','Scalers','MinMax')
standard_scaler_path = os.path.join('.','Scalers','Standard')

# %% [markdown]
# ## Load Original Scaled Data

# %%
complete_data_scaled_shuffled = pd.read_csv('Dataset_Scaled_Shuffled.csv')
print('Shuffled dataset loaded.')
# Out:
# Shuffled dataset loaded.

# %% [markdown]
# ## Load MinMax Scalers

# %%
# Create an empty list to put all the scalers
minmax_scalers = []

for i in range(len(complete_data_scaled_shuffled.columns)):
    
    scaler_filename = os.path.join(minmax_scaler_path,'scaler{}.save'.format(i))
    minmax_scaler = joblib.load(scaler_filename)
    
    minmax_scalers.append(minmax_scaler)

# %% [markdown]
# ## Load Standard Scalers

# %%
# Create an empty list to put all the loaded scalers
standard_scalers = []

for i in range(len(complete_data_scaled_shuffled.columns)):
    
    scaler_filename = os.path.join(standard_scaler_path,'scaler{}.save'.format(i))
    standard_scaler = joblib.load(scaler_filename)
    
    standard_scalers.append(standard_scaler)

# %% [markdown]
# ## Inverse Scale Data
#
# Using the original MinMax

# %%
# First, inverse transform all original values from the test_set
original_data_inverse = complete_data_scaled_shuffled.copy()

for i in range(len(complete_data_scaled_shuffled.columns)):
    
    col_name = complete_data_scaled_shuffled.columns[i]
    
    values = original_data_inverse[col_name].values
    values = values.astype('float64')
    values = values.reshape(values.shape[0],1)
    
    original_data_inverse[col_name] = minmax_scalers[i].inverse_transform(values)
    
    print('Success with feature: {}'.format(col_name))
# Out:
# Success with feature: Year
# Success with feature: Vehicle_Code
# Success with feature: Manufacturer_Code
# Success with feature: Displacement
# Success with feature: Fuel_System
# Success with feature: Gears
# Success with feature: Transmission_Code
# Success with feature: ETW
# Success with feature: HP
# Success with feature: Drive_System_Code
# Success with feature: Fuel_Code
# Success with feature: V_avg
# Success with feature: V_max
# Success with feature: V_std
# Success with feature: a_pos
# Success with feature: a_neg
# Success with feature: Peak_pos
# Success with feature: Peak_neg
# Success with feature: HC
# Success with feature: CO
# Success with feature: CO2
# Success with feature: Nox

# %% [markdown]
# ## Analyze Manufacturers

# %%
# Get a list of the available manufacturers (each one has a code)
manufacturers = original_data_inverse['Manufacturer_Code'].unique()
original_data_inverse['Manufacturer_Code'].unique()
# Out:
# array([493., 661., 716., 241., 733., 244., 498., 608., 171., 126., 853.,
#        122., 662., 382., 838., 727., 278., 929., 964., 892., 578., 745.,
#        229., 381., 996., 688., 416., 376., 554., 107., 571., 164., 867.,
#        613., 413., 457., 815., 590., 680., 753., 137., 490., 983., 352.,
#        315., 296., 642., 721., 335., 309., 354., 634., 566., 683., 597.,
#        531., 115., 397., 920., 568., 172., 436., 947., 125., 849., 467.,
#        186., 419., 487.])

# %%
# Create empty list
manuf_by_entries_list = []

# Loop over the manufacturer codes
for i in manufacturers:
    
    # Create a temporary DataFrame where there are only entries that match the current manufactuer code
    # Get the length of that temporary DataFrame
    num_cars = len(original_data_inverse[original_data_inverse.Manufacturer_Code == i])
    
    # Append the manufacturer code and the number of entries to the empty list
    manuf_by_entries_list.append([i, num_cars])

# Turn the list into a DataFrame
manuf_by_entries = pd.DataFrame(manuf_by_entries_list)

# Rename the columns
manuf_by_entries.columns = ['Manufacturer', 'Num_Cars']

# Sort by number of entries from largest to smallest
manuf_by_entries.sort_values(by=['Num_Cars'], inplace=True, ascending=False)

# Reset the index to make it cleaner
manuf_by_entries.reset_index(drop=True, inplace=True)

#----------------------------------------------
# Create a database using only the top manufacturer

# Save the top manufacturer into a variable
top_manufacturer = manuf_by_entries['Manufacturer'][0]
top_manufacturer_entries = manuf_by_entries['Num_Cars'][0]
print('Top Manufacturer: {:.0f}'.format(top_manufacturer))
print('Number of Entries = {}'.format(top_manufacturer_entries))
print('-------------------------')

# Create the dataset
top_manufacturer_data = original_data_inverse[original_data_inverse.Manufacturer_Code == top_manufacturer]
print('Created Data Set: Top Manufacturer Data')
print('-------------------------')

'''
#----------------------------------------------
# Create a database using only manufacturers with more than 500 entries

# Create variable with minimum number of entries
min_entries = 500

# Create a list to store the manufacturers that have less than 500 entries
small_manufacturers = manuf_by_entries[manuf_by_entries.Num_Cars <= min_entries]['Manufacturer'].values

# Loop over the list above and drop all the small manufacturers
manufacturers_500_data = original_data_inverse.copy()

for i in small_manufacturers:
    manufacturers_500_data = manufacturers_500_data[manufacturers_500_data.Manufacturer_Code != i]
    rows = manufacturers_500_data.shape[0]
    
    print('Dropped Manufacturer: {:.0f}'.format(i))
    print('Rows = {:.0f}'.format(rows))
    
print('-------------------------')    
print('Created Data Set: Manufacturers 500 Data ')
'''
# Out:
# Top Manufacturer: 498
# Number of Entries = 9913
# -------------------------
# Created Data Set: Top Manufacturer Data
# -------------------------
# "\n#----------------------------------------------\n# Create a database using only manufacturers with more than 500 entries\n\n# Create variable with minimum number of entries\nmin_entries = 500\n\n# Create a list to store the manufacturers that have less than 500 entries\nsmall_manufacturers = manuf_by_entries[manuf_by_entries.Num_Cars <= min_entries]['Manufacturer'].values\n\n# Loop over the list above and drop all the small manufacturers\nmanufacturers_500_data = original_data_inverse.copy()\n\nfor i in small_manufacturers:\n    manufacturers_500_data = manufacturers_500_data[manufacturers_500_data.Manufacturer_Code != i]\n    rows = manufacturers_500_data.shape[0]\n    \n    print('Dropped Manufacturer: {:.0f}'.format(i))\n    print('Rows = {:.0f}'.format(rows))\n    \nprint('-------------------------')    \nprint('Created Data Set: Manufacturers 500 Data ')\n"

# %% [markdown]
# ## Scale Data
#
# Function to scale data according to an input that decides if it is a MinMax or a Standard Scaler

# %%
def scale_data(data, scaler_type):
    
    # Select the scalers
    if scaler_type == 'MinMax':
        
        scalers = minmax_scalers
        print('Using {} Scalers'.format(scaler_type))
        print('----------------------------------')
        
    if scaler_type == 'Standard':
        
        scalers = standard_scalers
        print('Using {} Scalers'.format(scaler_type))
        print('----------------------------------')
        
    # Scale the data
    
    # Copy the data set to avoid altering the original
    new_data_scaled = data.copy()
    
    # DROP THE VARIABLES WE DON'T WANT
    #new_data_scaled.drop(columns=['Fuel_Code', 'Drive_System_Code', 'Peak_pos', 'Peak_neg', 'ETW', 'a_pos', 'a_neg', 'HP'], 
                     #inplace=True)
    
    # Loop over the standard_scalers and perform the scaling operation on each column
    for i in range(len(new_data_scaled.columns)):

        col_name = new_data_scaled.columns[i]

        values = new_data_scaled[col_name].values
        values = values.astype('float64')
        values = values.reshape(values.shape[0],1)

        new_data_scaled[col_name] = scalers[i].fit_transform(values)

        print('Success with feature: {}'.format(col_name))
    
    print('----------------------------------')
    
    return new_data_scaled

# %%
scaler_types = ['MinMax']

# %%
data_standard_scaled = scale_data(top_manufacturer_data, 'Standard')
# Out:
# Using Standard Scalers
# ----------------------------------
# Success with feature: Year
# Success with feature: Vehicle_Code
# Success with feature: Manufacturer_Code
# Success with feature: Displacement
# Success with feature: Fuel_System
# Success with feature: Gears
# Success with feature: Transmission_Code
# Success with feature: ETW
# Success with feature: HP
# Success with feature: Drive_System_Code
# Success with feature: Fuel_Code
# Success with feature: V_avg
# Success with feature: V_max
# Success with feature: V_std
# Success with feature: a_pos
# Success with feature: a_neg
# Success with feature: Peak_pos
# Success with feature: Peak_neg
# Success with feature: HC
# Success with feature: CO
# Success with feature: CO2
# Success with feature: Nox
# ----------------------------------

# %%
data_minmax_scaled = scale_data(top_manufacturer_data, 'MinMax')
# Out:
# Using MinMax Scalers
# ----------------------------------
# Success with feature: Year
# Success with feature: Vehicle_Code
# Success with feature: Manufacturer_Code
# Success with feature: Displacement
# Success with feature: Fuel_System
# Success with feature: Gears
# Success with feature: Transmission_Code
# Success with feature: ETW
# Success with feature: HP
# Success with feature: Drive_System_Code
# Success with feature: Fuel_Code
# Success with feature: V_avg
# Success with feature: V_max
# Success with feature: V_std
# Success with feature: a_pos
# Success with feature: a_neg
# Success with feature: Peak_pos
# Success with feature: Peak_neg
# Success with feature: HC
# Success with feature: CO
# Success with feature: CO2
# Success with feature: Nox
# ----------------------------------

# %% [markdown]
# ## Prepare Data
#
# Function to prepare data based on the database input, which depends on the souce (Top or 500) and the scaler

# %%
# Get number of data points
data_points = top_manufacturer_data.shape[0]

# Set sizes for train, dev, test sets
train_percent = 0.8
train_size = round(train_percent*data_points)

if (data_points-train_size)%2 == 0:
    dev_size = int((data_points-train_size)/2)
    test_size = dev_size
    print('Train Size = {}'.format(train_size))
    print('Dev Size = {}'.format(dev_size))
    print('Test Size = {}'.format(test_size))
    print('Remainder = {}'.format(train_size+dev_size+test_size-data_points))
    print('----------------------------------')

else:
    train_size = train_size-1
    dev_size = int((data_points-train_size)/2)
    test_size = dev_size 
    print('Train Size = {}'.format(train_size))
    print('Dev Size = {}'.format(dev_size))
    print('Test Size = {}'.format(test_size))
    print('Remainder = {}'.format(train_size+dev_size+test_size-data_points))
    print('----------------------------------')
# Out:
# Train Size = 7929
# Dev Size = 992
# Test Size = 992
# Remainder = 0
# ----------------------------------

# %% [markdown]
# ## Prepare Datasets
#
# Create functions to modify the input variables and thus create different input sets

# %%
# Save the names of the columns in a list that can be looped
input_names = complete_data_scaled_shuffled.columns[:-4]

# %%
for variable in input_names:
    print('{}'.format(variable))
# Out:
# Year
# Vehicle_Code
# Manufacturer_Code
# Displacement
# Fuel_System
# Gears
# Transmission_Code
# ETW
# HP
# Drive_System_Code
# Fuel_Code
# V_avg
# V_max
# V_std
# a_pos
# a_neg
# Peak_pos
# Peak_neg

# %%
def prepare_data_sets(data, drop_variable=None):
    
    # Create a local copy of the entire dataset
    data_scaled_shuffled = data.copy()
    
    if drop_variable != None:
        # Drop the variable that will be ignored during the run
        data_scaled_shuffled.drop(columns=drop_variable, inplace=True)
        print('{} Column Dropped'.format(drop_variable))
    
    print('Preparing Data-sets')
    # Divide data into train, dev, and test sets
    train_set = data_scaled_shuffled[ : train_size]
    dev_set = data_scaled_shuffled[train_size : train_size+dev_size]
    test_set = data_scaled_shuffled[train_size+dev_size : train_size+dev_size+test_size]

    # Reset index for all sets
    train_set = train_set.reset_index(drop=True)
    dev_set = dev_set.reset_index(drop=True)
    test_set = test_set.reset_index(drop=True)

    # Get values
    train_set_values = train_set.values
    dev_set_values = dev_set.values
    test_set_values = test_set.values
    
    # Number of emissions: HC, CO, CO2, NOX
    n_out = 4
    
    print('Splitting into inputs and outputs')
    # SLICING: [start row:end row , start column:end column]
    # Split into inputs and outputs
    x_train = train_set_values[:,:-n_out]
    x_dev = dev_set_values[:,:-n_out]
    x_test = test_set_values[:,:-n_out]
    
    print('Inputs = {}'.format(x_train.shape[1]))
    
    # Get the outputs (only HC)
    HC_train = train_set_values[:,-n_out]
    HC_dev = dev_set_values[:,-n_out]
    HC_test = test_set_values[:,-n_out]
    
    print('Data-sets complete')
    print('----------------------------------')
    
    return x_train, x_dev, x_test, HC_train, HC_dev, HC_test

# %%
def get_test_inverse(scaler_type):
    
    # Select the scalers
    if scaler_type == 'MinMax':
        
        scalers = minmax_scalers
        
    if scaler_type == 'Standard':
        
        scalers = standard_scalers
        
    #----------------------------------

    # Inverse transform the TEST DATA to be able to calculate the error further down
    test_set_scaled = top_manufacturer_data[train_size+dev_size : train_size+dev_size+test_size]
    test_set_inverse = test_set_scaled.copy()

    for i in range(np.size(top_manufacturer_data.columns)):

        col_name = top_manufacturer_data.columns[i]

        values = test_set_inverse[col_name].values
        values = values.astype('float64')
        values = values.reshape(values.shape[0],1)

        test_set_inverse[col_name] = scalers[i].inverse_transform(values)

    print('Success creating inverse test set')
    print('----------------------------------')
    
    return test_set_inverse

# %% [markdown]
# ## PCA
#
# Create a function that creates a PCA instance and with that PCA instance creates a new x_train

# %%
def create_pca_set(variance_amount, x_train, x_dev, x_test):
    
    if variance_amount < 1:
    
        print('Create PCA Instance')
        pca = PCA(variance_amount)

        print('Fit PCA Instance')
        pca.fit(x_train)
        print('Number of Components = {}'.format(pca.n_components_))

        print('Create New Input Training Set')
        new_x_train = pca.transform(x_train)

        print('Create New Input Dev Set')
        new_x_dev = pca.transform(x_dev)

        print('Create New Input Test Set')
        new_x_test = pca.transform(x_test)
        
    else:
        
        new_x_train = x_train
        new_x_dev = x_dev
        new_x_test = x_test

    print('----------------------------------')
    
    return new_x_train, new_x_dev, new_x_test

# %%
pca_options = [1, 0.99, 0.90]

# %% [markdown]
# -----------------
# ## Models

# %% [markdown]
# #### Basics

# %%
# Mini-batch size, epochs
batch_size = 64
epochs = 300

# %% [markdown]
# #### Hyper-Parameter Space

# %%
# Activation functions to try
names_activations = ['LReLU']
    # A function has to be called so that a new instance of the function can be created in each layer
def get_activation(name):
    
    if name == 'ReLU':
        function = advanced_activations.ReLU()
    if name == 'LReLU':
        function = advanced_activations.LeakyReLU()
        
    return function

#--------------------------------------------------------------------------------- 

output_activations = ['linear']

#--------------------------------------------------------------------------------- 

# Dropout rate to be tried
dropouts = [0.2]

# %% [markdown]
# #### Build Model

# %%
def build_model(number, x_train, activation_name, output, dd):
    
    # Create model
    model = Sequential(name='Model_{}'.format(number))

    model.add(Dense(256, input_dim=x_train.shape[1]))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(128))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(64))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(32))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(16))
    model.add(get_activation(activation_name))
    model.add(Dropout(dd))
    model.add(BatchNormalization())

    model.add(Dense(1))
    
    if output == 'ReLU':
        model.add(advanced_activations.ReLU())

    #Compile model
    model.compile(loss=losses.mean_absolute_percentage_error, optimizer=optimizers.Adam(), metrics = ['accuracy'])
    
    print('{} Created'.format(model.name))
    print('----------------------------------')
    
    return model

# %% [markdown]
# #### Train Model

# %%
def train_models(model, x_train, y_train, x_dev, y_dev):
    
    print('{} - Training'.format(model.name))
    print('- Started on {} at {}'.format(str(datetime.datetime.now())[5:-16], str(datetime.datetime.now())[11:-10]))
    # Start timer
    start_time = time.time()

    # fit network
    history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, 
                        validation_data=(x_dev, y_dev), verbose=0, shuffle=True)

    # End timer
    end_time = time.time() - start_time
    print('{} - Training Complete'.format(model.name))
    print('- Time: {:.3f} min'.format(end_time/60))
    print('- Loss = {:.5f}'.format(history.history['loss'][-1]))
    print('- Val Loss = {:.5f}'.format(history.history['val_loss'][-1]))
    print('----------------------------------')
        
    return history

# %% [markdown]
# #### Make Predictions and Calculate Error

# %%
# Function to define MSPE
def msp_error(true,pred):
    error = 100*np.sum(((true-pred)/true)**2)/np.size(true)
    return error

# %%
def predict_get_error(model, x_test, scaler_type, test_set_inverse):
    
        # Select the scalers
    if scaler_type == 'MinMax':
        
        scalers = minmax_scalers
        
    if scaler_type == 'Standard':
        
        scalers = standard_scalers  
    
    #------------------
    print('Predicting with {}'.format(model.name))
    scaled_predictions = model.predict(x_test)
    
    print('Inverse Scaling Operation') 
     
    # Inverse the scaling operation on the predictions
    predictions = scalers[-4].inverse_transform(scaled_predictions)
    
    print('- Prediction Mean = {:.5f}'.format(np.mean(predictions)))
    print('- Prediction Min = {:.5f}'.format(np.min(predictions)))
    print('- Prediction Max = {:.5f}'.format(np.max(predictions)))

    print('Calculating HC Error')
    mspe = msp_error(test_set_inverse['HC'].values, predictions)
        
    print('- HC Error  = {:.2e}'.format(mspe))
    print('----------------------------------')
    
    return mspe

# %% [markdown]
# #### Process Models and Rank with MSPE

# %%
def process_models():
    
    count = 1
    model_list = []
    history_list = []
    HC_error_list = []
        
    for scaler_type in scaler_types:

        for activation_name in names_activations:

            for output in output_activations:

                for dd in dropouts:
                    
                    for variable in input_names:

                        # Print model variables
                        print('Model_{} Variables:'.format(count))
                        print('- Loss: MAPE')
                        print('- Activation: {}'.format(activation_name))
                        print('- Output: {}'.format(output))
                        print('- Optimizer: Adam')
                        print('- Dropout: {}%'.format(dd*100))
                        print('- Scaler: {}'.format(scaler_type))
                        print('- Dropped: {}'.format(variable))
                        print('----------------------------------')
                        
                        data_scaled = data_minmax_scaled.copy()

                        # Prepare data-sets and create inputs and outputs
                        x_train, x_dev, x_test, y_train, y_dev, y_test = prepare_data_sets(data_scaled, variable)

                        # Create model
                        model = build_model(count, x_train, activation_name, output, dd)

                        # Train model
                        history = train_models(model, x_train, y_train, x_dev, y_dev)
                        history_list.append(history)

                        # Get test_set_inverse
                        test_set_inverse = get_test_inverse(scaler_type)

                        # Make predictions and calculate error
                        error = predict_get_error(model, x_test, scaler_type, test_set_inverse)

                        # Add error to error list
                        HC_error_list.append([model.name, scaler_type, activation_name, output, dd, variable, error])

                        # Announce one model process ended
                        print('============== MODEL {} PROCESS END =============='.format(count))
                        print(' ')

                        # Increase counter by 1
                        count = count+1

                        # Add TRAINED model to list
                        model_list.append(model)
                        
                        
    # Create TWO PCA database
    for variance_amount in pca_options:
        
        scaler_type = 'MinMax'
        activation_name = 'LReLU'
        output = 'linear'
        dd = 0.2
        
        # Print model variables
        print('Model_{} Variables:'.format(count))
        print('- Loss: MAPE')
        print('- Activation: {}'.format(activation_name))
        print('- Output: {}'.format(output))
        print('- Optimizer: Adam')
        print('- Dropout: {}%'.format(dd*100))
        print('- Scaler: {}'.format(scaler_type))
        print('- Variance: {}'.format(variance_amount))
        print('----------------------------------')
        
        # Prepare data-sets and create inputs and outputs
        old_x_train, old_x_dev, old_x_test, y_train, y_dev, y_test = prepare_data_sets(data_minmax_scaled)
        
        # Create PCA instance for the inputs
        x_train, x_dev, x_test = create_pca_set(variance_amount, old_x_train, old_x_dev, old_x_test)

        # Create model
        model = build_model(count, x_train, activation_name, output, dd)

        # Train model
        history = train_models(model, x_train, y_train, x_dev, y_dev)
        history_list.append(history)

        # Get test_set_inverse
        test_set_inverse = get_test_inverse(scaler_type)

        # Make predictions and calculate error
        error = predict_get_error(model, x_test, scaler_type, test_set_inverse)

        # Add error to error list
        HC_error_list.append([model.name, scaler_type, activation_name, output, dd, variance_amount, error])

        # Announce one model process ended
        print('============== MODEL {} PROCESS END =============='.format(count))
        print(' ')

        # Increase counter by 1
        count = count+1

        # Add TRAINED model to list
        model_list.append(model)
    
    #------------------------------------------------------------

    print('Creating DataFrame')                
    HC_error = pd.DataFrame(HC_error_list)

    print('Changing DataFrame column names')
    HC_error.columns = ['Model', 'Scaler', 'Activation', 'Output', 'Dropout', 'Variable/Variance', 'MSPE']

    print('Ranking Models')
    HC_error.sort_values(by=['MSPE'], inplace=True)

    count = 0
    
    return HC_error, model_list, history_list

# %%
HC_ranking, models, histories = process_models()
# Out:
# Model_1 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Year
# ----------------------------------
# Year Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_1 Created
# ----------------------------------
# Model_1 - Training
# - Started on 04-09 at 21:32
# Model_1 - Training Complete
# - Time: 8.315 min
# - Loss = 482.43511
# - Val Loss = 208.83346
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_1
# Inverse Scaling Operation
# - Prediction Mean = -0.01266
# - Prediction Min = -0.12968
# - Prediction Max = -0.01039
# Calculating HC Error
# - HC Error  = 3.49e+06
# ----------------------------------
# ============== MODEL 1 PROCESS END ==============
#
# Model_2 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Vehicle_Code
# ----------------------------------
# Vehicle_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_2 Created
# ----------------------------------
# Model_2 - Training
# - Started on 04-09 at 21:40
# Model_2 - Training Complete
# - Time: 8.269 min
# - Loss = 993.19366
# - Val Loss = 96.38753
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_2
# Inverse Scaling Operation
# - Prediction Mean = -0.00225
# - Prediction Min = -2.52738
# - Prediction Max = 0.00267
# Calculating HC Error
# - HC Error  = 1.13e+08
# ----------------------------------
# ============== MODEL 2 PROCESS END ==============
#
# Model_3 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Manufacturer_Code
# ----------------------------------
# Manufacturer_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_3 Created
# ----------------------------------
# Model_3 - Training
# - Started on 04-09 at 21:48
# Model_3 - Training Complete
# - Time: 8.351 min
# - Loss = 556.63008
# - Val Loss = 133.62065
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_3
# Inverse Scaling Operation
# - Prediction Mean = -0.00328
# - Prediction Min = -0.01472
# - Prediction Max = 0.14944
# Calculating HC Error
# - HC Error  = 1.51e+06
# ----------------------------------
# ============== MODEL 3 PROCESS END ==============
#
# Model_4 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Displacement
# ----------------------------------
# Displacement Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_4 Created
# ----------------------------------
# Model_4 - Training
# - Started on 04-09 at 21:57
# Model_4 - Training Complete
# - Time: 8.414 min
# - Loss = 977.40859
# - Val Loss = 188.63789
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_4
# Inverse Scaling Operation
# - Prediction Mean = 0.01378
# - Prediction Min = -1.25589
# - Prediction Max = 0.11280
# Calculating HC Error
# - HC Error  = 8.57e+07
# ----------------------------------
# ============== MODEL 4 PROCESS END ==============
#
# Model_5 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_System
# ----------------------------------
# Fuel_System Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_5 Created
# ----------------------------------
# Model_5 - Training
# - Started on 04-09 at 22:05
# Model_5 - Training Complete
# - Time: 8.556 min
# - Loss = 1039.90027
# - Val Loss = 143.43843
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_5
# Inverse Scaling Operation
# - Prediction Mean = -0.00488
# - Prediction Min = -0.00557
# - Prediction Max = -0.00187
# Calculating HC Error
# - HC Error  = 6.02e+05
# ----------------------------------
# ============== MODEL 5 PROCESS END ==============
#
# Model_6 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Gears
# ----------------------------------
# Gears Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_6 Created
# ----------------------------------
# Model_6 - Training
# - Started on 04-09 at 22:14
# Model_6 - Training Complete
# - Time: 8.521 min
# - Loss = 2183.69847
# - Val Loss = 96.46698
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_6
# Inverse Scaling Operation
# - Prediction Mean = 0.00207
# - Prediction Min = -0.02670
# - Prediction Max = 0.05759
# Calculating HC Error
# - HC Error  = 6.16e+05
# ----------------------------------
# ============== MODEL 6 PROCESS END ==============
#
# Model_7 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Transmission_Code
# ----------------------------------
# Transmission_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_7 Created
# ----------------------------------
# Model_7 - Training
# - Started on 04-09 at 22:22
# Model_7 - Training Complete
# - Time: 8.571 min
# - Loss = 373.22708
# - Val Loss = 97.25853
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_7
# Inverse Scaling Operation
# - Prediction Mean = 0.00484
# - Prediction Min = 0.00473
# - Prediction Max = 0.01294
# Calculating HC Error
# - HC Error  = 3.38e+05
# ----------------------------------
# ============== MODEL 7 PROCESS END ==============
#
# Model_8 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: ETW
# ----------------------------------
# ETW Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_8 Created
# ----------------------------------
# Model_8 - Training
# - Started on 04-09 at 22:31
# Model_8 - Training Complete
# - Time: 8.635 min
# - Loss = 1784.13897
# - Val Loss = 194.05928
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_8
# Inverse Scaling Operation
# - Prediction Mean = -0.00145
# - Prediction Min = -0.00921
# - Prediction Max = 0.57245
# Calculating HC Error
# - HC Error  = 4.04e+07
# ----------------------------------
# ============== MODEL 8 PROCESS END ==============
#
# Model_9 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: HP
# ----------------------------------
# HP Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_9 Created
# ----------------------------------
# Model_9 - Training
# - Started on 04-09 at 22:39
# Model_9 - Training Complete
# - Time: 8.797 min
# - Loss = 702.36017
# - Val Loss = 96.31674
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_9
# Inverse Scaling Operation
# - Prediction Mean = 0.00452
# - Prediction Min = 0.00228
# - Prediction Max = 1.15969
# Calculating HC Error
# - HC Error  = 2.27e+07
# ----------------------------------
# ============== MODEL 9 PROCESS END ==============
#
# Model_10 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Drive_System_Code
# ----------------------------------
# Drive_System_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_10 Created
# ----------------------------------
# Model_10 - Training
# - Started on 04-09 at 22:48
# Model_10 - Training Complete
# - Time: 8.785 min
# - Loss = 770.12101
# - Val Loss = 152.61838
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_10
# Inverse Scaling Operation
# - Prediction Mean = -0.00837
# - Prediction Min = -0.42251
# - Prediction Max = 0.00212
# Calculating HC Error
# - HC Error  = 1.30e+07
# ----------------------------------
# ============== MODEL 10 PROCESS END ==============
#
# Model_11 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_Code
# ----------------------------------
# Fuel_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_11 Created
# ----------------------------------
# Model_11 - Training
# - Started on 04-09 at 22:57
# Model_11 - Training Complete
# - Time: 8.849 min
# - Loss = 876.62836
# - Val Loss = 96.63872
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_11
# Inverse Scaling Operation
# - Prediction Mean = 0.00537
# - Prediction Min = -0.10514
# - Prediction Max = 0.15085
# Calculating HC Error
# - HC Error  = 2.33e+06
# ----------------------------------
# ============== MODEL 11 PROCESS END ==============
#
# Model_12 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_avg
# ----------------------------------
# V_avg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_12 Created
# ----------------------------------
# Model_12 - Training
# - Started on 04-09 at 23:06
# Model_12 - Training Complete
# - Time: 8.908 min
# - Loss = 412.74553
# - Val Loss = 289.70868
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_12
# Inverse Scaling Operation
# - Prediction Mean = -0.01268
# - Prediction Min = -0.11477
# - Prediction Max = 0.32746
# Calculating HC Error
# - HC Error  = 2.31e+07
# ----------------------------------
# ============== MODEL 12 PROCESS END ==============
#
# Model_13 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_max
# ----------------------------------
# V_max Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_13 Created
# ----------------------------------
# Model_13 - Training
# - Started on 04-09 at 23:15
# Model_13 - Training Complete
# - Time: 8.971 min
# - Loss = 1288.78506
# - Val Loss = 117.03789
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_13
# Inverse Scaling Operation
# - Prediction Mean = -0.00518
# - Prediction Min = -0.15782
# - Prediction Max = 0.00221
# Calculating HC Error
# - HC Error  = 8.10e+06
# ----------------------------------
# ============== MODEL 13 PROCESS END ==============
#
# Model_14 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_std
# ----------------------------------
# V_std Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_14 Created
# ----------------------------------
# Model_14 - Training
# - Started on 04-09 at 23:24
# Model_14 - Training Complete
# - Time: 9.021 min
# - Loss = 671.69915
# - Val Loss = 147.62262
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_14
# Inverse Scaling Operation
# - Prediction Mean = -0.00003
# - Prediction Min = -0.00539
# - Prediction Max = 0.33732
# Calculating HC Error
# - HC Error  = 9.67e+06
# ----------------------------------
# ============== MODEL 14 PROCESS END ==============
#
# Model_15 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_pos
# ----------------------------------
# a_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_15 Created
# ----------------------------------
# Model_15 - Training
# - Started on 04-09 at 23:33
# Model_15 - Training Complete
# - Time: 9.079 min
# - Loss = 1684.22162
# - Val Loss = 180.90204
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_15
# Inverse Scaling Operation
# - Prediction Mean = -0.01273
# - Prediction Min = -2.44009
# - Prediction Max = -0.00448
# Calculating HC Error
# - HC Error  = 1.68e+08
# ----------------------------------
# ============== MODEL 15 PROCESS END ==============
#
# Model_16 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_neg
# ----------------------------------
# a_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_16 Created
# ----------------------------------
# Model_16 - Training
# - Started on 04-09 at 23:42
# Model_16 - Training Complete
# - Time: 9.136 min
# - Loss = 197.68786
# - Val Loss = 148.47437
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_16
# Inverse Scaling Operation
# - Prediction Mean = -0.00640
# - Prediction Min = -0.15362
# - Prediction Max = -0.00464
# Calculating HC Error
# - HC Error  = 2.13e+06
# ----------------------------------
# ============== MODEL 16 PROCESS END ==============
#
# Model_17 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_pos
# ----------------------------------
# Peak_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_17 Created
# ----------------------------------
# Model_17 - Training
# - Started on 04-09 at 23:51
# Model_17 - Training Complete
# - Time: 9.242 min
# - Loss = 351.10349
# - Val Loss = 193.66288
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_17
# Inverse Scaling Operation
# - Prediction Mean = -0.00961
# - Prediction Min = -0.01951
# - Prediction Max = 0.18379
# Calculating HC Error
# - HC Error  = 3.22e+06
# ----------------------------------
# ============== MODEL 17 PROCESS END ==============
#
# Model_18 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_neg
# ----------------------------------
# Peak_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_18 Created
# ----------------------------------
# Model_18 - Training
# - Started on 04-10 at 00:00
# Model_18 - Training Complete
# - Time: 9.242 min
# - Loss = 796.09316
# - Val Loss = 148.65819
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_18
# Inverse Scaling Operation
# - Prediction Mean = -0.00713
# - Prediction Min = -0.82545
# - Prediction Max = -0.00503
# Calculating HC Error
# - HC Error  = 2.16e+07
# ----------------------------------
# ============== MODEL 18 PROCESS END ==============
#
# Model_19 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Year
# ----------------------------------
# Year Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_19 Created
# ----------------------------------
# Model_19 - Training
# - Started on 04-10 at 00:10
# Model_19 - Training Complete
# - Time: 9.330 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_19
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 19 PROCESS END ==============
#
# Model_20 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Vehicle_Code
# ----------------------------------
# Vehicle_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_20 Created
# ----------------------------------
# Model_20 - Training
# - Started on 04-10 at 00:19
# Model_20 - Training Complete
# - Time: 9.403 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_20
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 20 PROCESS END ==============
#
# Model_21 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Manufacturer_Code
# ----------------------------------
# Manufacturer_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_21 Created
# ----------------------------------
# Model_21 - Training
# - Started on 04-10 at 00:28
# Model_21 - Training Complete
# - Time: 9.445 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_21
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 21 PROCESS END ==============
#
# Model_22 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Displacement
# ----------------------------------
# Displacement Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_22 Created
# ----------------------------------
# Model_22 - Training
# - Started on 04-10 at 00:38
# Model_22 - Training Complete
# - Time: 9.533 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_22
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 22 PROCESS END ==============
#
# Model_23 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_System
# ----------------------------------
# Fuel_System Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_23 Created
# ----------------------------------
# Model_23 - Training
# - Started on 04-10 at 00:48
# Model_23 - Training Complete
# - Time: 9.593 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_23
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 23 PROCESS END ==============
#
# Model_24 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Gears
# ----------------------------------
# Gears Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_24 Created
# ----------------------------------
# Model_24 - Training
# - Started on 04-10 at 00:57
# Model_24 - Training Complete
# - Time: 9.863 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_24
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 24 PROCESS END ==============
#
# Model_25 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Transmission_Code
# ----------------------------------
# Transmission_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_25 Created
# ----------------------------------
# Model_25 - Training
# - Started on 04-10 at 01:07
# Model_25 - Training Complete
# - Time: 9.770 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_25
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 25 PROCESS END ==============
#
# Model_26 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: ETW
# ----------------------------------
# ETW Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_26 Created
# ----------------------------------
# Model_26 - Training
# - Started on 04-10 at 01:17
# Model_26 - Training Complete
# - Time: 9.881 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_26
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 26 PROCESS END ==============
#
# Model_27 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: HP
# ----------------------------------
# HP Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_27 Created
# ----------------------------------
# Model_27 - Training
# - Started on 04-10 at 01:27
# Model_27 - Training Complete
# - Time: 9.880 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_27
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 27 PROCESS END ==============
#
# Model_28 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Drive_System_Code
# ----------------------------------
# Drive_System_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_28 Created
# ----------------------------------
# Model_28 - Training
# - Started on 04-10 at 01:37
# Model_28 - Training Complete
# - Time: 9.966 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_28
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 28 PROCESS END ==============
#
# Model_29 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_Code
# ----------------------------------
# Fuel_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_29 Created
# ----------------------------------
# Model_29 - Training
# - Started on 04-10 at 01:47
# Model_29 - Training Complete
# - Time: 10.051 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_29
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 29 PROCESS END ==============
#
# Model_30 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_avg
# ----------------------------------
# V_avg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_30 Created
# ----------------------------------
# Model_30 - Training
# - Started on 04-10 at 01:57
# Model_30 - Training Complete
# - Time: 10.526 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_30
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 30 PROCESS END ==============
#
# Model_31 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_max
# ----------------------------------
# V_max Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_31 Created
# ----------------------------------
# Model_31 - Training
# - Started on 04-10 at 02:07
# Model_31 - Training Complete
# - Time: 11.126 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_31
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 31 PROCESS END ==============
#
# Model_32 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_std
# ----------------------------------
# V_std Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_32 Created
# ----------------------------------
# Model_32 - Training
# - Started on 04-10 at 02:19
# Model_32 - Training Complete
# - Time: 11.239 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_32
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 32 PROCESS END ==============
#
# Model_33 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_pos
# ----------------------------------
# a_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_33 Created
# ----------------------------------
# Model_33 - Training
# - Started on 04-10 at 02:30
# Model_33 - Training Complete
# - Time: 11.428 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_33
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 33 PROCESS END ==============
#
# Model_34 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_neg
# ----------------------------------
# a_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_34 Created
# ----------------------------------
# Model_34 - Training
# - Started on 04-10 at 02:41
# Model_34 - Training Complete
# - Time: 11.540 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_34
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 34 PROCESS END ==============
#
# Model_35 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_pos
# ----------------------------------
# Peak_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_35 Created
# ----------------------------------
# Model_35 - Training
# - Started on 04-10 at 02:53
# Model_35 - Training Complete
# - Time: 12.933 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_35
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 35 PROCESS END ==============
#
# Model_36 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_neg
# ----------------------------------
# Peak_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_36 Created
# ----------------------------------
# Model_36 - Training
# - Started on 04-10 at 03:06
# Model_36 - Training Complete
# - Time: 13.110 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_36
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 36 PROCESS END ==============
#
# Model_37 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Year
# ----------------------------------
# Year Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_37 Created
# ----------------------------------
# Model_37 - Training
# - Started on 04-10 at 03:19
# Model_37 - Training Complete
# - Time: 13.196 min
# - Loss = 1487.02968
# - Val Loss = 104.42008
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_37
# Inverse Scaling Operation
# - Prediction Mean = 0.00282
# - Prediction Min = -0.07203
# - Prediction Max = 0.01283
# Calculating HC Error
# - HC Error  = 1.15e+06
# ----------------------------------
# ============== MODEL 37 PROCESS END ==============
#
# Model_38 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Vehicle_Code
# ----------------------------------
# Vehicle_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_38 Created
# ----------------------------------
# Model_38 - Training
# - Started on 04-10 at 03:32
# Model_38 - Training Complete
# - Time: 12.874 min
# - Loss = 1381.16091
# - Val Loss = 129.42323
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_38
# Inverse Scaling Operation
# - Prediction Mean = 0.00661
# - Prediction Min = -0.00392
# - Prediction Max = 0.33045
# Calculating HC Error
# - HC Error  = 2.22e+07
# ----------------------------------
# ============== MODEL 38 PROCESS END ==============
#
# Model_39 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Manufacturer_Code
# ----------------------------------
# Manufacturer_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_39 Created
# ----------------------------------
# Model_39 - Training
# - Started on 04-10 at 03:45
# Model_39 - Training Complete
# - Time: 12.259 min
# - Loss = 957.38395
# - Val Loss = 139.74297
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_39
# Inverse Scaling Operation
# - Prediction Mean = -0.01050
# - Prediction Min = -0.20710
# - Prediction Max = -0.00173
# Calculating HC Error
# - HC Error  = 9.98e+06
# ----------------------------------
# ============== MODEL 39 PROCESS END ==============
#
# Model_40 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Displacement
# ----------------------------------
# Displacement Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_40 Created
# ----------------------------------
# Model_40 - Training
# - Started on 04-10 at 03:58
# Model_40 - Training Complete
# - Time: 11.761 min
# - Loss = 1014.34317
# - Val Loss = 128.76963
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_40
# Inverse Scaling Operation
# - Prediction Mean = 0.00824
# - Prediction Min = -0.05564
# - Prediction Max = 0.26875
# Calculating HC Error
# - HC Error  = 1.89e+07
# ----------------------------------
# ============== MODEL 40 PROCESS END ==============
#
# Model_41 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_System
# ----------------------------------
# Fuel_System Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_41 Created
# ----------------------------------
# Model_41 - Training
# - Started on 04-10 at 04:09
# Model_41 - Training Complete
# - Time: 11.279 min
# - Loss = 623.03023
# - Val Loss = 163.87442
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_41
# Inverse Scaling Operation
# - Prediction Mean = -0.00756
# - Prediction Min = -0.04486
# - Prediction Max = 0.02390
# Calculating HC Error
# - HC Error  = 3.38e+06
# ----------------------------------
# ============== MODEL 41 PROCESS END ==============
#
# Model_42 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Gears
# ----------------------------------
# Gears Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_42 Created
# ----------------------------------
# Model_42 - Training
# - Started on 04-10 at 04:21
# Model_42 - Training Complete
# - Time: 11.402 min
# - Loss = 1746.20747
# - Val Loss = 134.28809
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_42
# Inverse Scaling Operation
# - Prediction Mean = -0.00513
# - Prediction Min = -0.08395
# - Prediction Max = 0.02230
# Calculating HC Error
# - HC Error  = 5.40e+06
# ----------------------------------
# ============== MODEL 42 PROCESS END ==============
#
# Model_43 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Transmission_Code
# ----------------------------------
# Transmission_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_43 Created
# ----------------------------------
# Model_43 - Training
# - Started on 04-10 at 04:32
# Model_43 - Training Complete
# - Time: 11.655 min
# - Loss = 945.81278
# - Val Loss = 114.17874
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_43
# Inverse Scaling Operation
# - Prediction Mean = 0.00546
# - Prediction Min = -0.06799
# - Prediction Max = 0.17356
# Calculating HC Error
# - HC Error  = 8.51e+06
# ----------------------------------
# ============== MODEL 43 PROCESS END ==============
#
# Model_44 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: ETW
# ----------------------------------
# ETW Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_44 Created
# ----------------------------------
# Model_44 - Training
# - Started on 04-10 at 04:44
# Model_44 - Training Complete
# - Time: 11.660 min
# - Loss = 1346.22252
# - Val Loss = 110.27066
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_44
# Inverse Scaling Operation
# - Prediction Mean = -0.00100
# - Prediction Min = -0.03098
# - Prediction Max = 0.01704
# Calculating HC Error
# - HC Error  = 5.75e+05
# ----------------------------------
# ============== MODEL 44 PROCESS END ==============
#
# Model_45 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: HP
# ----------------------------------
# HP Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_45 Created
# ----------------------------------
# Model_45 - Training
# - Started on 04-10 at 04:56
# Model_45 - Training Complete
# - Time: 11.801 min
# - Loss = 1814.40346
# - Val Loss = 151.43048
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_45
# Inverse Scaling Operation
# - Prediction Mean = -0.00539
# - Prediction Min = -0.02032
# - Prediction Max = 0.06482
# Calculating HC Error
# - HC Error  = 1.56e+06
# ----------------------------------
# ============== MODEL 45 PROCESS END ==============
#
# Model_46 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Drive_System_Code
# ----------------------------------
# Drive_System_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_46 Created
# ----------------------------------
# Model_46 - Training
# - Started on 04-10 at 05:07
# Model_46 - Training Complete
# - Time: 11.811 min
# - Loss = 1497.63769
# - Val Loss = 128.16222
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_46
# Inverse Scaling Operation
# - Prediction Mean = -0.00030
# - Prediction Min = -0.01249
# - Prediction Max = 0.17439
# Calculating HC Error
# - HC Error  = 4.80e+06
# ----------------------------------
# ============== MODEL 46 PROCESS END ==============
#
# Model_47 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_Code
# ----------------------------------
# Fuel_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_47 Created
# ----------------------------------
# Model_47 - Training
# - Started on 04-10 at 05:19
# Model_47 - Training Complete
# - Time: 12.035 min
# - Loss = 817.26454
# - Val Loss = 200.86968
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_47
# Inverse Scaling Operation
# - Prediction Mean = 0.00298
# - Prediction Min = -0.12333
# - Prediction Max = 0.34075
# Calculating HC Error
# - HC Error  = 3.14e+07
# ----------------------------------
# ============== MODEL 47 PROCESS END ==============
#
# Model_48 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_avg
# ----------------------------------
# V_avg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_48 Created
# ----------------------------------
# Model_48 - Training
# - Started on 04-10 at 05:31
# Model_48 - Training Complete
# - Time: 12.179 min
# - Loss = 230.94818
# - Val Loss = 131.74702
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_48
# Inverse Scaling Operation
# - Prediction Mean = 0.00302
# - Prediction Min = -0.11719
# - Prediction Max = 0.02405
# Calculating HC Error
# - HC Error  = 3.55e+06
# ----------------------------------
# ============== MODEL 48 PROCESS END ==============
#
# Model_49 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_max
# ----------------------------------
# V_max Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_49 Created
# ----------------------------------
# Model_49 - Training
# - Started on 04-10 at 05:44
# Model_49 - Training Complete
# - Time: 12.386 min
# - Loss = 1243.72659
# - Val Loss = 141.09491
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_49
# Inverse Scaling Operation
# - Prediction Mean = 0.00458
# - Prediction Min = -0.17095
# - Prediction Max = 0.11896
# Calculating HC Error
# - HC Error  = 1.52e+07
# ----------------------------------
# ============== MODEL 49 PROCESS END ==============
#
# Model_50 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_std
# ----------------------------------
# V_std Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_50 Created
# ----------------------------------
# Model_50 - Training
# - Started on 04-10 at 05:56
# Model_50 - Training Complete
# - Time: 12.386 min
# - Loss = 8923.05824
# - Val Loss = 249.68030
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_50
# Inverse Scaling Operation
# - Prediction Mean = 0.01841
# - Prediction Min = -0.22383
# - Prediction Max = 0.07095
# Calculating HC Error
# - HC Error  = 2.41e+07
# ----------------------------------
# ============== MODEL 50 PROCESS END ==============
#
# Model_51 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_pos
# ----------------------------------
# a_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_51 Created
# ----------------------------------
# Model_51 - Training
# - Started on 04-10 at 06:09
# Model_51 - Training Complete
# - Time: 12.515 min
# - Loss = 1851.13022
# - Val Loss = 246.32155
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_51
# Inverse Scaling Operation
# - Prediction Mean = 0.00678
# - Prediction Min = -0.05871
# - Prediction Max = 0.27039
# Calculating HC Error
# - HC Error  = 4.13e+07
# ----------------------------------
# ============== MODEL 51 PROCESS END ==============
#
# Model_52 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_neg
# ----------------------------------
# a_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_52 Created
# ----------------------------------
# Model_52 - Training
# - Started on 04-10 at 06:21
# Model_52 - Training Complete
# - Time: 12.739 min
# - Loss = 1926.61215
# - Val Loss = 116.94319
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_52
# Inverse Scaling Operation
# - Prediction Mean = -0.00070
# - Prediction Min = -0.15120
# - Prediction Max = 0.01296
# Calculating HC Error
# - HC Error  = 5.51e+06
# ----------------------------------
# ============== MODEL 52 PROCESS END ==============
#
# Model_53 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_pos
# ----------------------------------
# Peak_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_53 Created
# ----------------------------------
# Model_53 - Training
# - Started on 04-10 at 06:34
# Model_53 - Training Complete
# - Time: 12.826 min
# - Loss = 1352.11353
# - Val Loss = 124.48327
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_53
# Inverse Scaling Operation
# - Prediction Mean = 0.00693
# - Prediction Min = -0.00444
# - Prediction Max = 0.13668
# Calculating HC Error
# - HC Error  = 8.01e+06
# ----------------------------------
# ============== MODEL 53 PROCESS END ==============
#
# Model_54 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_neg
# ----------------------------------
# Peak_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_54 Created
# ----------------------------------
# Model_54 - Training
# - Started on 04-10 at 06:47
# Model_54 - Training Complete
# - Time: 12.889 min
# - Loss = 1372.69614
# - Val Loss = 101.76920
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_54
# Inverse Scaling Operation
# - Prediction Mean = -0.00189
# - Prediction Min = -0.18246
# - Prediction Max = 0.03326
# Calculating HC Error
# - HC Error  = 9.69e+06
# ----------------------------------
# ============== MODEL 54 PROCESS END ==============
#
# Model_55 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Year
# ----------------------------------
# Year Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_55 Created
# ----------------------------------
# Model_55 - Training
# - Started on 04-10 at 07:00
# Model_55 - Training Complete
# - Time: 13.003 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# ...
# Manufacturer_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_57 Created
# ----------------------------------
# Model_57 - Training
# - Started on 04-10 at 07:26
# Model_57 - Training Complete
# - Time: 13.254 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_57
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 57 PROCESS END ==============
#
# Model_58 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Displacement
# ----------------------------------
# Displacement Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_58 Created
# ----------------------------------
# Model_58 - Training
# - Started on 04-10 at 07:40
# Model_58 - Training Complete
# - Time: 13.384 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_58
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 58 PROCESS END ==============
#
# Model_59 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_System
# ----------------------------------
# Fuel_System Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_59 Created
# ----------------------------------
# Model_59 - Training
# - Started on 04-10 at 07:53
# Model_59 - Training Complete
# - Time: 13.556 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_59
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 59 PROCESS END ==============
#
# Model_60 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Gears
# ----------------------------------
# Gears Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_60 Created
# ----------------------------------
# Model_60 - Training
# - Started on 04-10 at 08:07
# Model_60 - Training Complete
# - Time: 14.314 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_60
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 60 PROCESS END ==============
#
# Model_61 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Transmission_Code
# ----------------------------------
# Transmission_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_61 Created
# ----------------------------------
# Model_61 - Training
# - Started on 04-10 at 08:21
# Model_61 - Training Complete
# - Time: 14.424 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_61
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 61 PROCESS END ==============
#
# Model_62 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: ETW
# ----------------------------------
# ETW Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_62 Created
# ----------------------------------
# Model_62 - Training
# - Started on 04-10 at 08:36
# Model_62 - Training Complete
# - Time: 14.716 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_62
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 62 PROCESS END ==============
#
# Model_63 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: HP
# ----------------------------------
# HP Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_63 Created
# ----------------------------------
# Model_63 - Training
# - Started on 04-10 at 08:50
# Model_63 - Training Complete
# - Time: 14.793 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_63
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 63 PROCESS END ==============
#
# Model_64 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Drive_System_Code
# ----------------------------------
# Drive_System_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_64 Created
# ----------------------------------
# Model_64 - Training
# - Started on 04-10 at 09:05
# Model_64 - Training Complete
# - Time: 14.913 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_64
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 64 PROCESS END ==============
#
# Model_65 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Fuel_Code
# ----------------------------------
# Fuel_Code Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_65 Created
# ----------------------------------
# Model_65 - Training
# - Started on 04-10 at 09:20
# Model_65 - Training Complete
# - Time: 15.043 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_65
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 65 PROCESS END ==============
#
# Model_66 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_avg
# ----------------------------------
# V_avg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_66 Created
# ----------------------------------
# Model_66 - Training
# - Started on 04-10 at 09:35
# Model_66 - Training Complete
# - Time: 15.266 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_66
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 66 PROCESS END ==============
#
# Model_67 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_max
# ----------------------------------
# V_max Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_67 Created
# ----------------------------------
# Model_67 - Training
# - Started on 04-10 at 09:51
# Model_67 - Training Complete
# - Time: 15.501 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_67
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 67 PROCESS END ==============
#
# Model_68 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: V_std
# ----------------------------------
# V_std Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_68 Created
# ----------------------------------
# Model_68 - Training
# - Started on 04-10 at 10:06
# Model_68 - Training Complete
# - Time: 16.351 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_68
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 68 PROCESS END ==============
#
# Model_69 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_pos
# ----------------------------------
# a_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_69 Created
# ----------------------------------
# Model_69 - Training
# - Started on 04-10 at 10:23
# Model_69 - Training Complete
# - Time: 16.423 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_69
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 69 PROCESS END ==============
#
# Model_70 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: a_neg
# ----------------------------------
# a_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_70 Created
# ----------------------------------
# Model_70 - Training
# - Started on 04-10 at 10:39
# Model_70 - Training Complete
# - Time: 17.532 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_70
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 70 PROCESS END ==============
#
# Model_71 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_pos
# ----------------------------------
# Peak_pos Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_71 Created
# ----------------------------------
# Model_71 - Training
# - Started on 04-10 at 10:57
# Model_71 - Training Complete
# - Time: 16.572 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_71
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 71 PROCESS END ==============
#
# Model_72 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Dropped: Peak_neg
# ----------------------------------
# Peak_neg Column Dropped
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 17
# Data-sets complete
# ----------------------------------
# Model_72 Created
# ----------------------------------
# Model_72 - Training
# - Started on 04-10 at 11:14
# Model_72 - Training Complete
# - Time: 18.395 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_72
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 72 PROCESS END ==============
#
# Model_73 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Variance: 0.99
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Create PCA Instance
# Fit PCA Instance
# Number of Components = 8
# Create New Input Training Set
# Create New Input Dev Set
# Create New Input Test Set
# ----------------------------------
# Model_73 Created
# ----------------------------------
# Model_73 - Training
# - Started on 04-10 at 11:32
# Model_73 - Training Complete
# - Time: 17.921 min
# - Loss = 1002.28940
# - Val Loss = 112.61494
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_73
# Inverse Scaling Operation
# - Prediction Mean = 0.00649
# - Prediction Min = -0.07253
# - Prediction Max = 0.24167
# Calculating HC Error
# - HC Error  = 1.12e+07
# ----------------------------------
# ============== MODEL 73 PROCESS END ==============
#
# Model_74 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# - Variance: 0.9
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Create PCA Instance
# Fit PCA Instance
# Number of Components = 4
# Create New Input Training Set
# Create New Input Dev Set
# Create New Input Test Set
# ----------------------------------
# Model_74 Created
# ----------------------------------
# Model_74 - Training
# - Started on 04-10 at 11:50
# Model_74 - Training Complete
# - Time: 17.591 min
# - Loss = 2252.01900
# - Val Loss = 103.21967
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_74
# Inverse Scaling Operation
# - Prediction Mean = 0.00489
# - Prediction Min = -0.03150
# - Prediction Max = 0.04055
# Calculating HC Error
# - HC Error  = 2.23e+06
# ----------------------------------
# ============== MODEL 74 PROCESS END ==============
#
# Creating DataFrame
# Changing DataFrame column names
# Ranking Models

# %%
HC_ranking
# Out:
#        Model  Scaler Activation  Output  Dropout  Variable/Variance  \
# 21  Model_22  MinMax       ReLU    ReLU      0.2       Displacement
# 20  Model_21  MinMax       ReLU    ReLU      0.2  Manufacturer_Code
# 58  Model_59  MinMax      LReLU    ReLU      0.2        Fuel_System
# 22  Model_23  MinMax       ReLU    ReLU      0.2        Fuel_System
# 23  Model_24  MinMax       ReLU    ReLU      0.2              Gears
# 24  Model_25  MinMax       ReLU    ReLU      0.2  Transmission_Code
# 25  Model_26  MinMax       ReLU    ReLU      0.2                ETW
# 26  Model_27  MinMax       ReLU    ReLU      0.2                 HP
# 27  Model_28  MinMax       ReLU    ReLU      0.2  Drive_System_Code
# 28  Model_29  MinMax       ReLU    ReLU      0.2          Fuel_Code
# 29  Model_30  MinMax       ReLU    ReLU      0.2              V_avg
# 30  Model_31  MinMax       ReLU    ReLU      0.2              V_max
# 31  Model_32  MinMax       ReLU    ReLU      0.2              V_std
# 32  Model_33  MinMax       ReLU    ReLU      0.2              a_pos
# 33  Model_34  MinMax       ReLU    ReLU      0.2              a_neg
# 34  Model_35  MinMax       ReLU    ReLU      0.2           Peak_pos
# 19  Model_20  MinMax       ReLU    ReLU      0.2       Vehicle_Code
# 35  Model_36  MinMax       ReLU    ReLU      0.2           Peak_neg
# 18  Model_19  MinMax       ReLU    ReLU      0.2               Year
# 61  Model_62  MinMax      LReLU    ReLU      0.2                ETW
# 71  Model_72  MinMax      LReLU    ReLU      0.2           Peak_neg
# 54  Model_55  MinMax      LReLU    ReLU      0.2               Year
# 70  Model_71  MinMax      LReLU    ReLU      0.2           Peak_pos
# 55  Model_56  MinMax      LReLU    ReLU      0.2       Vehicle_Code
# 56  Model_57  MinMax      LReLU    ReLU      0.2  Manufacturer_Code
# 69  Model_70  MinMax      LReLU    ReLU      0.2              a_neg
# 60  Model_61  MinMax      LReLU    ReLU      0.2  Transmission_Code
# 68  Model_69  MinMax      LReLU    ReLU      0.2              a_pos
# 66  Model_67  MinMax      LReLU    ReLU      0.2              V_max
# 65  Model_66  MinMax      LReLU    ReLU      0.2              V_avg
# ..       ...     ...        ...     ...      ...                ...
# 73  Model_74  MinMax      LReLU  linear      0.2                0.9
# 10  Model_11  MinMax       ReLU  linear      0.2          Fuel_Code
# 16  Model_17  MinMax       ReLU  linear      0.2           Peak_pos
# 40  Model_41  MinMax      LReLU  linear      0.2        Fuel_System
# 0    Model_1  MinMax       ReLU  linear      0.2               Year
# 47  Model_48  MinMax      LReLU  linear      0.2              V_avg
# 45  Model_46  MinMax      LReLU  linear      0.2  Drive_System_Code
# 41  Model_42  MinMax      LReLU  linear      0.2              Gears
# 51  Model_52  MinMax      LReLU  linear      0.2              a_neg
# 52  Model_53  MinMax      LReLU  linear      0.2           Peak_pos
# 12  Model_13  MinMax       ReLU  linear      0.2              V_max
# 42  Model_43  MinMax      LReLU  linear      0.2  Transmission_Code
# 13  Model_14  MinMax       ReLU  linear      0.2              V_std
# 53  Model_54  MinMax      LReLU  linear      0.2           Peak_neg
# 38  Model_39  MinMax      LReLU  linear      0.2  Manufacturer_Code
# 72  Model_73  MinMax      LReLU  linear      0.2               0.99
# 9   Model_10  MinMax       ReLU  linear      0.2  Drive_System_Code
# 48  Model_49  MinMax      LReLU  linear      0.2              V_max
# 39  Model_40  MinMax      LReLU  linear      0.2       Displacement
# 17  Model_18  MinMax       ReLU  linear      0.2           Peak_neg
# 37  Model_38  MinMax      LReLU  linear      0.2       Vehicle_Code
# 8    Model_9  MinMax       ReLU  linear      0.2                 HP
# 11  Model_12  MinMax       ReLU  linear      0.2              V_avg
# 49  Model_50  MinMax      LReLU  linear      0.2              V_std
# 46  Model_47  MinMax      LReLU  linear      0.2          Fuel_Code
# 7    Model_8  MinMax       ReLU  linear      0.2                ETW
# 50  Model_51  MinMax      LReLU  linear      0.2              a_pos
# 3    Model_4  MinMax       ReLU  linear      0.2       Displacement
# 1    Model_2  MinMax       ReLU  linear      0.2       Vehicle_Code
# 14  Model_15  MinMax       ReLU  linear      0.2              a_pos
#
#             MSPE
# 21  9.760168e+04
# 20  9.760168e+04
# 58  9.760168e+04
# 22  9.760168e+04
# 23  9.760168e+04
# 24  9.760168e+04
# 25  9.760168e+04
# 26  9.760168e+04
# 27  9.760168e+04
# 28  9.760168e+04
# 29  9.760168e+04
# 30  9.760168e+04
# 31  9.760168e+04
# 32  9.760168e+04
# 33  9.760168e+04
# 34  9.760168e+04
# 19  9.760168e+04
# 35  9.760168e+04
# 18  9.760168e+04
# 61  9.760168e+04
# 71  9.760168e+04
# 54  9.760168e+04
# 70  9.760168e+04
# 55  9.760168e+04
# 56  9.760168e+04
# 69  9.760168e+04
# 60  9.760168e+04
# 68  9.760168e+04
# 66  9.760168e+04
# 65  9.760168e+04
# ..           ...
# 73  2.233575e+06
# 10  2.333617e+06
# 16  3.219856e+06
# 40  3.380762e+06
# 0   3.491520e+06
# 47  3.547598e+06
# 45  4.800888e+06
# 41  5.402384e+06
# 51  5.513838e+06
# 52  8.008802e+06
# 12  8.101627e+06
# 42  8.513230e+06
# 13  9.666213e+06
# 53  9.685409e+06
# 38  9.976097e+06
# 72  1.119968e+07
# 9   1.298474e+07
# 48  1.518227e+07
# 39  1.890406e+07
# 17  2.163895e+07
# 37  2.215254e+07
# 8   2.267597e+07
# 11  2.307797e+07
# 49  2.408673e+07
# 46  3.143596e+07
# 7   4.036585e+07
# 50  4.133518e+07
# 3   8.568508e+07
# 1   1.126759e+08
# 14  1.679276e+08
#
# [74 rows x 7 columns]

# %%
number = 5
print(models[number].name + ' ' + HC_ranking['Scaler'][number])

# %%
epoch_vector=np.linspace(1,epochs,epochs)

for i in range(len(models)):
    model = models[i]
    history = histories[i]
    activation = HC_ranking['Activation'][i]
    output = HC_ranking['Output'][i]
    variable = HC_ranking['Variable/Variance'][i]
    
    model.save(os.path.join(output_path,'{}_{}_{}_{}.h5'.format(model.name, activation, output, variable)))
    
    hist_data =[epoch_vector,history.history['loss'],history.history['val_loss']]
    hist_data =pd.DataFrame(hist_data).transpose()
    hist_data.columns=['Epochs','loss','val_loss']
    
    hist_data.to_csv(os.path.join(output_path,'Training_History_{}.csv'.format(model.name)),index=False)

# %%
# I forgot to train the models using all 18 input variables

# %%
def process_models_2():
    
    count = 75
    model_list = []
    history_list = []
    HC_error_list = []
        
    for scaler_type in scaler_types:

        for activation_name in names_activations:

            for output in output_activations:

                for dd in dropouts:

                    # Print model variables
                    print('Model_{} Variables:'.format(count))
                    print('- Loss: MAPE')
                    print('- Activation: {}'.format(activation_name))
                    print('- Output: {}'.format(output))
                    print('- Optimizer: Adam')
                    print('- Dropout: {}%'.format(dd*100))
                    print('- Scaler: {}'.format(scaler_type))
                    print('----------------------------------')

                    data_scaled = data_minmax_scaled.copy()

                    # Prepare data-sets and create inputs and outputs
                    x_train, x_dev, x_test, y_train, y_dev, y_test = prepare_data_sets(data_scaled)

                    # Create model
                    model = build_model(count, x_train, activation_name, output, dd)

                    # Train model
                    history = train_models(model, x_train, y_train, x_dev, y_dev)
                    history_list.append(history)

                    # Get test_set_inverse
                    test_set_inverse = get_test_inverse(scaler_type)

                    # Make predictions and calculate error
                    error = predict_get_error(model, x_test, scaler_type, test_set_inverse)

                    # Add error to error list
                    HC_error_list.append([model.name, scaler_type, activation_name, output, dd, variable, error])

                    # Announce one model process ended
                    print('============== MODEL {} PROCESS END =============='.format(count))
                    print(' ')

                    # Increase counter by 1
                    count = count+1

                    # Add TRAINED model to list
                    model_list.append(model)
                        
    #------------------------------------------------------------

    print('Creating DataFrame')                
    HC_error = pd.DataFrame(HC_error_list)

    print('Changing DataFrame column names')
    HC_error.columns = ['Model', 'Scaler', 'Activation', 'Output', 'Dropout', 'Variable/Variance', 'MSPE']

    print('Ranking Models')
    HC_error.sort_values(by=['MSPE'], inplace=True)

    count = 0
    
    return HC_error, model_list, history_list

# %%
HC_ranking_2, models_2, histories_2 = process_models_2()
# Out:
# Model_75 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Model_75 Created
# ----------------------------------
# Model_75 - Training
# - Started on 04-12 at 13:02
# Model_75 - Training Complete
# - Time: 18.813 min
# - Loss = 928.70895
# - Val Loss = 125.84016
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_75
# Inverse Scaling Operation
# - Prediction Mean = 0.00279
# - Prediction Min = -1.02577
# - Prediction Max = 0.00982
# Calculating HC Error
# - HC Error  = 5.86e+07
# ----------------------------------
# ============== MODEL 75 PROCESS END ==============
#
# Model_76 Variables:
# - Loss: MAPE
# - Activation: ReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Model_76 Created
# ----------------------------------
# Model_76 - Training
# - Started on 04-12 at 13:21
# Model_76 - Training Complete
# - Time: 18.797 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_76
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 76 PROCESS END ==============
#
# Model_77 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: linear
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Model_77 Created
# ----------------------------------
# Model_77 - Training
# - Started on 04-12 at 13:40
# Model_77 - Training Complete
# - Time: 19.457 min
# - Loss = 1609.53582
# - Val Loss = 121.29999
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_77
# Inverse Scaling Operation
# - Prediction Mean = 0.00069
# - Prediction Min = -0.01513
# - Prediction Max = 0.07549
# Calculating HC Error
# - HC Error  = 1.46e+06
# ----------------------------------
# ============== MODEL 77 PROCESS END ==============
#
# Model_78 Variables:
# - Loss: MAPE
# - Activation: LReLU
# - Output: ReLU
# - Optimizer: Adam
# - Dropout: 20.0%
# - Scaler: MinMax
# ----------------------------------
# Preparing Data-sets
# Splitting into inputs and outputs
# Inputs = 18
# Data-sets complete
# ----------------------------------
# Model_78 Created
# ----------------------------------
# Model_78 - Training
# - Started on 04-12 at 13:59
# Model_78 - Training Complete
# - Time: 18.613 min
# - Loss = 99.98739
# - Val Loss = 100.00000
# ----------------------------------
# Success creating inverse test set
# ----------------------------------
# Predicting with Model_78
# Inverse Scaling Operation
# - Prediction Mean = 0.00006
# - Prediction Min = 0.00006
# - Prediction Max = 0.00006
# Calculating HC Error
# - HC Error  = 9.76e+04
# ----------------------------------
# ============== MODEL 78 PROCESS END ==============
#
# Creating DataFrame
# Changing DataFrame column names
# Ranking Models

# %%
HC_ranking_2.drop(columns=['Variable/Variance'], inplace=True)

# %%
HC_ranking_2
# Out:
#       Model  Scaler Activation  Output  Dropout          MSPE
# 1  Model_76  MinMax       ReLU    ReLU      0.2  9.760168e+04
# 3  Model_78  MinMax      LReLU    ReLU      0.2  9.760168e+04
# 2  Model_77  MinMax      LReLU  linear      0.2  1.458004e+06
# 0  Model_75  MinMax       ReLU  linear      0.2  5.858767e+07

# %%
for i in range(len(models_2)):
    model = models_2[i]
    history = histories_2[i]
    activation = HC_ranking_2['Activation'][i]
    output = HC_ranking_2['Output'][i]
    variable = 'ALL'
    
    model.save(os.path.join(output_path,'{}_{}_{}_{}.h5'.format(model.name, activation, output, variable)))
    
    hist_data =[epoch_vector,history.history['loss'],history.history['val_loss']]
    hist_data =pd.DataFrame(hist_data).transpose()
    hist_data.columns=['Epochs','loss','val_loss']
    
    hist_data.to_csv(os.path.join(output_path,'Training_History_{}.csv'.format(model.name)),index=False)

# %% [markdown]
# ## Next Steps

# %% [markdown]
# The models and the training histories will be moved to foldr **Gen 9**.
#
# Nothing in this notebook yielded an improvement in performance.
#
# Nothing else will be done as time does not permit it.
#
# Next steps in the proyect is doing an investigation into how to correct vehicle emissions to account for the vehicle age (and maybe alitude), and write the final document.
